# %% [markdown]
# <a href="https://colab.research.google.com/github/DajanaSanchez/BirdMigrationClimateAnalysis/blob/main/climate_data_processing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Unmount Google Drive
drive.flush_and_unmount()

# Remount Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Drive not mounted, so nothing to flush and unmount.
# Mounted at /content/drive

# %%
import pandas as pd
import os
import tarfile
import glob
from google.colab import files

# Define file paths in Google Drive
BASE_DIR = "/content/drive/MyDrive/climate_data/"
PRECIP_DATA = os.path.join(BASE_DIR, "ghcn-m_v4.00.00_prcp_s16970101_e20241231_c20250105.tar")
PRECIP_INVENTORY = os.path.join(BASE_DIR, "ghcn-m_v4_prcp_inventory.txt")
TEMP_METADATA = os.path.join(BASE_DIR, "ghcnm.tavg.v4.0.1.20250127.qfe.inv")
TEMP_DATA = os.path.join(BASE_DIR, "ghcnm.tavg.v4.0.1.20250127.qfe.dat")

# %%
#counting the number of files in the tar raw data file that start with MX, CA, US for validating purposes
import tarfile
import os

VALID_COUNTRIES = {'CA', 'US', 'MX'}

def count_country_files_in_tar(tar_path):
    """ Count files by country code in the tar archive """
    country_counts = {code: 0 for code in VALID_COUNTRIES}

    with tarfile.open(tar_path, "r:") as tar:
        for member in tar.getmembers():
            if member.name.endswith('.csv'):
                country_code = os.path.basename(member.name)[:2]
                if country_code in country_counts:
                    country_counts[country_code] += 1

    print("📊 File count by country:")
    for country, count in country_counts.items():
        print(f"{country}: {count} files")

    return country_counts


count_country_files_in_tar(PRECIP_DATA)
# Out:
# 📊 File count by country:
# CA: 8785 files
# US: 63213 files
# MX: 5314 files
# {'CA': 8785, 'US': 63213, 'MX': 5314}

# %%
# Deletes all extracted files
import shutil
shutil.rmtree("/content/precip_data", ignore_errors=True)

# %%
#extracting US, CA, MX CSV files from raw data tar file
import os
import tarfile
import pandas as pd

VALID_COUNTRIES = {'CA', 'US', 'MX'}

#Extracts only CSV files for selected countries while ensuring a consistent 11-column structure.

def extract_tar_fixed(tar_path, extract_to="/content/drive/MyDrive/climate_data/precip_data"):

    if not os.path.exists(extract_to):
        os.makedirs(extract_to)

    print(f"📂 Extracting files from {tar_path}...")

    extracted_files = []  # Track extracted files

    with tarfile.open(tar_path, "r:*") as tar:
        for member in tar.getmembers():
            filename = os.path.basename(member.name)

            # ✅ Check if the file belongs to a valid country and is a CSV
            if filename.endswith('.csv') and filename[:2] in VALID_COUNTRIES:
                tar.extract(member, path=extract_to)
                extracted_file_path = os.path.join(extract_to, filename)

                # 🚀 Read file in a way that avoids parser errors
                try:
                    df = pd.read_csv(extracted_file_path, header=None, dtype=str, on_bad_lines='skip')

                    # 🚨 Identify files with inconsistent columns
                    if df.shape[1] == 12:
                        print(f"⚠️ {filename} has 12 columns! Fixing extra Station Name column...")
                        df.drop(columns=[2], inplace=True)  # Drop second column

                    # Ensure it has exactly 11 columns
                    if df.shape[1] != 11:
                      print(f"❌ {filename} still has {df.shape[1]} columns! Check manually.")

                    # ✅ Save the cleaned file
                    df.to_csv(extracted_file_path, index=False, header=False)
                    extracted_files.append(filename)

                except pd.errors.ParserError as e:
                    print(f"❌ Parser error in {filename}: {e}")
                    continue  # Skip this file

    print(f"✅ Successfully extracted and standardized {len(extracted_files)} files with 11 columns.")
    return extract_to

extracted_precip = extract_tar_fixed(PRECIP_DATA, extract_to="/content/precip_data")
# Out:
# 📂 Extracting files from /content/drive/MyDrive/climate_data/ghcn-m_v4.00.00_prcp_s16970101_e20241231_c20250105.tar...
# ⚠️ CA004063753.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ CA008103780.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ CA008403045.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXM00076258.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXM00076382.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXM00076525.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXM00076685.csv has 12 columns! Fixing extra Station Name column...
# ❌ Parser error in MXM00076692.csv: Error tokenizing data. C error: EOF inside string starting at row 1169
# ⚠️ MXM00076741.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXM00076775.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXMLP076220.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXMLP076373.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXMLP076402.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXMLP076573.csv has 12 columns! Fixing extra Station Name column...
# ⚠️ MXMLP076746.csv has 12 columns! Fixing extra Station Name column...
# ✅ Successfully extracted and standardized 77311 files with 11 columns.

# %%
#validating structure of files that had 12 columns to ensure proper structure
import os

extract_to = "/content/precip_data"  # Change if the extracted files are in a different directory
file_name = "MXMLP076746.csv"  # Change this to the file you want to check

# Check if the file exists
file_path = os.path.join(extract_to, file_name)

if os.path.exists(file_path):
    print(f"📌 Found file: {file_path}")
else:
    print("❌ File not found. Check the filename or extraction path.")



if os.path.exists(file_path):
    df = pd.read_csv(file_path, header=None, dtype=str)

    print(f"📊 {file_name} has {df.shape[1]} columns and {df.shape[0]} rows.")
    print(df.head())  # Show the first few rows to verify structure
else:
    print("❌ File not found.")
# Out:
# 📌 Found file: /content/precip_data/MXMLP076746.csv
# 📊 MXMLP076746.csv has 11 columns and 240 rows.
#             0                                  1          2           3   \
# 0  MXMLP076746                        "CD OBREGON    18.5333    -92.6500
# 1  MXMLP076746                        "CD OBREGON    18.5333    -92.6500
# 2  MXMLP076746                        "CD OBREGON    18.5333    -92.6500
# 3  MXMLP076746                        "CD OBREGON    18.5333    -92.6500
# 4  MXMLP076746                        "CD OBREGON    18.5333    -92.6500
#
#          4       5       6  7  8  9       10
# 0    -999.9  196101     342        R  111732
# 1    -999.9  196102      -1        R  111732
# 2    -999.9  196103      -1        R  111732
# 3    -999.9  196104      -1        R  111732
# 4    -999.9  196105      -1        R  111732

# %%
#moving extracted files to Google Drive
import shutil
import os

# Define paths
local_extracted_path = "/content/precip_data"
drive_destination_path = "/content/drive/MyDrive/climate_data/precip_data"

for filename in os.listdir(local_extracted_path):
    if filename.endswith(".csv"):
        src = os.path.join(local_extracted_path, filename)
        dst = os.path.join(drive_destination_path, filename)
        shutil.move(src, dst)

print(f"✅ Moved all extracted files to Google Drive: {drive_destination_path}")

# %%
# Loading precipitation metadata and filtering to only include CA, MX, and US
import pandas as pd
import re

# List of valid country codes
VALID_COUNTRIES = {'CA', 'US', 'MX'}

def load_precip_metadata(file_path):
    print("Loading precipitation metadata...")
    try:
        data = []
        with open(file_path, 'r') as file:
            for line in file:
                match = re.match(r"^(\S+)\s+([\d\.-]+)\s+([\d\.-]+)\s+([\d\.-]+)\s+(\S{2})?\s+(.+?)\s+(\d{5})?\s+(\d{4})?\s+(\d{4})?$", line.strip())
                if match:
                    groups = list(match.groups())

                    # Extract country code from the first two characters of Station_ID
                    country_code = groups[0][:2]  # First two characters

                    # Keep only CA, MX, US stations
                    if country_code not in VALID_COUNTRIES:
                        continue  # Skip this record

                    if groups[4] is None or groups[4] not in VALID_COUNTRIES:
                        if groups[4] is not None:
                            groups[5] = groups[4] + " " + groups[5]
                        groups[4] = None

                    data.append(groups)
                else:
                    print(f"⚠ Warning: Skipping malformed line: {line.strip()}")

        col_names = ["Station_ID", "Latitude", "Longitude", "Elevation", "State", "Station_Name", "WMO_ID", "First_Year", "Last_Year"]
        df = pd.DataFrame(data, columns=col_names)
        df[["Latitude", "Longitude", "Elevation", "First_Year", "Last_Year"]] = df[["Latitude", "Longitude", "Elevation", "First_Year", "Last_Year"]].apply(pd.to_numeric, errors='coerce')

        print(f"✅ Successfully loaded {df.shape[0]} rows and {df.shape[1]} columns (filtered for CA, MX, US).")
        return df
    except Exception as e:
        print(f"❌ Error loading metadata: {e}")
        return None

# Run the function and load filtered precipitation metadata
precip_metadata = load_precip_metadata(PRECIP_INVENTORY)

# Define the output path in Google Drive
precip_metadata_file = "/content/drive/MyDrive/climate_data/precip_metadata_filtered.csv"

# Save the metadata DataFrame to a CSV file
precip_metadata.to_csv(precip_metadata_file, index=False)

print(f"✅ Filtered precipitation metadata saved to {precip_metadata_file}")
# Out:
# Loading precipitation metadata...
# ✅ Successfully loaded 77312 rows and 9 columns (filtered for CA, MX, US).
# ✅ Filtered precipitation metadata saved to /content/drive/MyDrive/climate_data/precip_metadata_filtered.csv

# %%
#validating country codes in cleaned metadata file
print("Unique country codes in the filtered dataset:")
print(precip_metadata['Station_ID'].str[:2].unique())
# Out:
# Unique country codes in the filtered dataset:
# ['CA' 'MX' 'US']

# %%
import os

processed_precip_file = "/content/drive/MyDrive/climate_data/processed_precipitation.csv"

# Delete the incorrect processed file
if os.path.exists(processed_precip_file):
    os.remove(processed_precip_file)
    print("✅ Deleted the old processed_precipitation.csv file.")
else:
    print("⚠️ No existing processed file found.")
# Out:
# ⚠️ No existing processed file found.

# %%
import os
import glob
import pandas as pd
from concurrent.futures import ThreadPoolExecutor, as_completed

# Define paths
local_extracted_path = "/content/precip_data"  # Directory where extracted files are stored
output_csv_path = "/content/merged_precip_data.csv"  # Final merged CSV file
error_log = "/content/error_log.txt"  # Log file for issues

# List all CSV files in the directory
csv_files = glob.glob(os.path.join(local_extracted_path, "*.csv"))

print(f"📂 Found {len(csv_files)} CSV files to merge.")


def process_file(file):
    """ Reads and processes a single CSV file in chunks, ensuring a valid 11-column structure. """
    try:
        chunk_list = []

        for chunk in pd.read_csv(file,
            header=None,
            dtype=str,
            engine="python",
            sep=",",
            quotechar='"',
            skipinitialspace=True,
            chunksize=500000  # Process large files in chunks
        ):

            # 🚨 Assign Column Names
            chunk.columns = [
                "Station_ID", "Station_Name", "Latitude", "Longitude", "Elevation",
                "YearMonth", "Precip_Value", "Measurement_Flag", "QC_Flag", "Source_Flag", "Source_Index"
            ]

            # 🚨 Convert Precip_Value to mm, replace -1 values
            chunk["Precip_Value"] = pd.to_numeric(chunk["Precip_Value"], errors="coerce").replace(-1, 0) / 10

            # 🚨 Format YearMonth as YYYY-MM
            chunk["YearMonth"] = chunk["YearMonth"].str.strip()  # Remove spaces
            chunk["YearMonth"] = chunk["YearMonth"].apply(lambda x: f"{x[:4]}-{x[4:]}" if len(x) == 6 else x)

            chunk_list.append(chunk)

        return pd.concat(chunk_list, ignore_index=True) if chunk_list else None

    except Exception as e:
        with open(error_log, "a") as log:
            log.write(f"{file} - Error: {e}\n")
        print(f"❌ Error processing file {file}: {e}")
        return None


def merge_precipitation_data_parallel(directory, output_filename="merged_precip_data.csv", num_workers=4):
    """ Merges multiple precipitation files in parallel, logs errors, and saves a single CSV file. """

    output_file = os.path.join("/content", output_filename)

    all_files = glob.glob(os.path.join(directory, "**", "*.csv"), recursive=True)
    if not all_files:
        print(f"❌ No CSV files found in {directory}")
        return None

    print(f"🚀 Starting parallel merging with {num_workers} threads...")

    first_write = not os.path.exists(output_file)  # Write header only if file doesn't exist

    with ThreadPoolExecutor(max_workers=num_workers) as executor:
        future_to_file = {executor.submit(process_file, file): file for file in all_files}

        for future in as_completed(future_to_file):
            file = future_to_file[future]
            try:
                df = future.result()
                if df is not None:
                    df.to_csv(output_file, mode='a', index=False, header=first_write)
                    first_write = False  # Ensure header is written only once
                    print(f"✅ Processed and merged: {file}")

            except Exception as e:
                with open(error_log, "a") as log:
                    log.write(f"{file} - Processing failed: {e}\n")
                print(f"❌ Failed to merge {file}: {e}")

    # 🚀 Ensure the error log is properly saved
    if os.path.exists(error_log):
        print(f"⚠️ Error log saved at {error_log}")
    else:
        print("❌ Error log not found. Something went wrong.")

    print(f"✅ Merging complete! Data saved to {output_file}")
    return output_file


# Run the merging function on local files
merged_precip_file = merge_precipitation_data_parallel(local_extracted_path, num_workers=4)
# Out:
# Streaming output truncated to the last 5000 lines.
# ✅ Processed and merged: /content/precip_data/MXN00015200.csv
# ✅ Processed and merged: /content/precip_data/USC00515675.csv
# ✅ Processed and merged: /content/precip_data/US1HIHI0086.csv
# ✅ Processed and merged: /content/precip_data/USC00299820.csv
# ✅ Processed and merged: /content/precip_data/US1TXCML117.csv
# ✅ Processed and merged: /content/precip_data/USC00350897.csv
# ✅ Processed and merged: /content/precip_data/US1ORCC0108.csv
# ✅ Processed and merged: /content/precip_data/US1SDED0013.csv
# ✅ Processed and merged: /content/precip_data/US1WAKP0048.csv
# ✅ Processed and merged: /content/precip_data/USC00413472.csv
# ✅ Processed and merged: /content/precip_data/USC00041967.csv
# ✅ Processed and merged: /content/precip_data/US1COBA0029.csv
# ✅ Processed and merged: /content/precip_data/US1ILLG0015.csv
# ✅ Processed and merged: /content/precip_data/US1RIPR0053.csv
# ✅ Processed and merged: /content/precip_data/CA004024120.csv
# ✅ Processed and merged: /content/precip_data/US1MABA0083.csv
# ✅ Processed and merged: /content/precip_data/USC00253485.csv
# ✅ Processed and merged: /content/precip_data/USC00338810.csv
# ✅ Processed and merged: /content/precip_data/US1MDPG0006.csv
# ✅ Processed and merged: /content/precip_data/US10DUND011.csv
# ✅ Processed and merged: /content/precip_data/US1MOSS0048.csv
# ✅ Processed and merged: /content/precip_data/CA006139149.csv
# ✅ Processed and merged: /content/precip_data/US1MNDK0070.csv
# ✅ Processed and merged: /content/precip_data/USC00519142.csv
# ✅ Processed and merged: /content/precip_data/US1MIWY0070.csv
# ✅ Processed and merged: /content/precip_data/USC00484303.csv
# ✅ Processed and merged: /content/precip_data/US1INPL0008.csv
# ✅ Processed and merged: /content/precip_data/USC00273486.csv
# ✅ Processed and merged: /content/precip_data/US1TXBXR189.csv
# ✅ Processed and merged: /content/precip_data/USC00105678.csv
# ✅ Processed and merged: /content/precip_data/US1TNDV0101.csv
# ✅ Processed and merged: /content/precip_data/MXN00012110.csv
# ✅ Processed and merged: /content/precip_data/MXN00031025.csv
# ✅ Processed and merged: /content/precip_data/USW00004781.csv
# ✅ Processed and merged: /content/precip_data/US1WALN0006.csv
# ✅ Processed and merged: /content/precip_data/USC00107255.csv
# ✅ Processed and merged: /content/precip_data/US1NCMT0006.csv
# ✅ Processed and merged: /content/precip_data/USC00417547.csv
# ✅ Processed and merged: /content/precip_data/USC00153241.csv
# ✅ Processed and merged: /content/precip_data/CA001010720.csv
# ✅ Processed and merged: /content/precip_data/US1AZMR0063.csv
# ✅ Processed and merged: /content/precip_data/US1LAEB0072.csv
# ✅ Processed and merged: /content/precip_data/CA001074276.csv
# ✅ Processed and merged: /content/precip_data/CA00106CDL0.csv
# ✅ Processed and merged: /content/precip_data/US1KYKN0017.csv
# ✅ Processed and merged: /content/precip_data/US1GAHS0006.csv
# ✅ Processed and merged: /content/precip_data/USC00352654.csv
# ✅ Processed and merged: /content/precip_data/US1SDPN0066.csv
# ✅ Processed and merged: /content/precip_data/US1NHHL0102.csv
# ✅ Processed and merged: /content/precip_data/US1SCBF0123.csv
# ✅ Processed and merged: /content/precip_data/USC00395735.csv
# ✅ Processed and merged: /content/precip_data/US1IALN0009.csv
# ✅ Processed and merged: /content/precip_data/USC00085756.csv
# ✅ Processed and merged: /content/precip_data/US1TXVZ0002.csv
# ✅ Processed and merged: /content/precip_data/USC00119469.csv
# ✅ Processed and merged: /content/precip_data/CA007041020.csv
# ✅ Processed and merged: /content/precip_data/MXN00019055.csv
# ✅ Processed and merged: /content/precip_data/US1NYUL0017.csv
# ✅ Processed and merged: /content/precip_data/US1ILLV0010.csv
# ✅ Processed and merged: /content/precip_data/MXN00028015.csv
# ✅ Processed and merged: /content/precip_data/US1CANV0057.csv
# ✅ Processed and merged: /content/precip_data/USC00487846.csv
# ✅ Processed and merged: /content/precip_data/MXN00010151.csv
# ✅ Processed and merged: /content/precip_data/US1OKWH0005.csv
# ✅ Processed and merged: /content/precip_data/USC00318560.csv
# ✅ Processed and merged: /content/precip_data/USC00311582.csv
# ✅ Processed and merged: /content/precip_data/US1COAD0107.csv
# ✅ Processed and merged: /content/precip_data/CA008403669.csv
# ✅ Processed and merged: /content/precip_data/US1PALC0011.csv
# ✅ Processed and merged: /content/precip_data/MXN00004066.csv
# ✅ Processed and merged: /content/precip_data/US1PAWN4056.csv
# ✅ Processed and merged: /content/precip_data/US1ALBL0013.csv
# ✅ Processed and merged: /content/precip_data/CA006159510.csv
# ✅ Processed and merged: /content/precip_data/USC00413401.csv
# ✅ Processed and merged: /content/precip_data/USC00469168.csv
# ✅ Processed and merged: /content/precip_data/US1NHHL0103.csv
# ✅ Processed and merged: /content/precip_data/MXN00016105.csv
# ✅ Processed and merged: /content/precip_data/CA007020860.csv
# ✅ Processed and merged: /content/precip_data/US1TXBXR545.csv
# ✅ Processed and merged: /content/precip_data/CA003012190.csv
# ✅ Processed and merged: /content/precip_data/CA006040081.csv
# ✅ Processed and merged: /content/precip_data/MXN00020183.csv
# ✅ Processed and merged: /content/precip_data/US10DEUE003.csv
# ✅ Processed and merged: /content/precip_data/US1CASD0217.csv
# ✅ Processed and merged: /content/precip_data/US1VAFX0111.csv
# ✅ Processed and merged: /content/precip_data/US1AZMH0002.csv
# ✅ Processed and merged: /content/precip_data/USC00469355.csv
# ✅ Processed and merged: /content/precip_data/US1INOR0032.csv
# ✅ Processed and merged: /content/precip_data/US1FLSS0034.csv
# ✅ Processed and merged: /content/precip_data/USC00255250.csv
# ✅ Processed and merged: /content/precip_data/US1INRN0007.csv
# ✅ Processed and merged: /content/precip_data/US1NCJH0060.csv
# ✅ Processed and merged: /content/precip_data/US1TNSQ0008.csv
# ✅ Processed and merged: /content/precip_data/US1TXLV0002.csv
# ✅ Processed and merged: /content/precip_data/US1INPT0126.csv
# ✅ Processed and merged: /content/precip_data/USC00297638.csv
# ✅ Processed and merged: /content/precip_data/US1COEP0253.csv
# ✅ Processed and merged: /content/precip_data/US10KEAR016.csv
# ✅ Processed and merged: /content/precip_data/US1WIWS0010.csv
# ✅ Processed and merged: /content/precip_data/US1AZCN0166.csv
# ✅ Processed and merged: /content/precip_data/MXN00018078.csv
# ✅ Processed and merged: /content/precip_data/USC00502352.csv
# ✅ Processed and merged: /content/precip_data/US1TXWK0028.csv
# ✅ Processed and merged: /content/precip_data/US1KSFI0012.csv
# ✅ Processed and merged: /content/precip_data/US1OKEL0003.csv
# ✅ Processed and merged: /content/precip_data/MXN00017093.csv
# ✅ Processed and merged: /content/precip_data/US1TXLL0008.csv
# ✅ Processed and merged: /content/precip_data/MXN00026305.csv
# ✅ Processed and merged: /content/precip_data/US1SDMH0046.csv
# ✅ Processed and merged: /content/precip_data/USC00487990.csv
# ✅ Processed and merged: /content/precip_data/US1FLDV0020.csv
# ✅ Processed and merged: /content/precip_data/US1NCLN0002.csv
# ✅ Processed and merged: /content/precip_data/US1TXCML029.csv
# ✅ Processed and merged: /content/precip_data/CA008206440.csv
# ✅ Processed and merged: /content/precip_data/CA0040190LN.csv
# ✅ Processed and merged: /content/precip_data/US1ALCT0025.csv
# ✅ Processed and merged: /content/precip_data/US1HIHI0067.csv
# ✅ Processed and merged: /content/precip_data/MXN00001103.csv
# ✅ Processed and merged: /content/precip_data/US1ORJC0031.csv
# ✅ Processed and merged: /content/precip_data/USC00195891.csv
# ✅ Processed and merged: /content/precip_data/US1TXDW0030.csv
# ✅ Processed and merged: /content/precip_data/US1NMBR0348.csv
# ✅ Processed and merged: /content/precip_data/US1TXCSS006.csv
# ✅ Processed and merged: /content/precip_data/USC00058184.csv
# ✅ Processed and merged: /content/precip_data/USS0022E10S.csv
# ✅ Processed and merged: /content/precip_data/CA008502799.csv
# ✅ Processed and merged: /content/precip_data/USC00238770.csv
# ✅ Processed and merged: /content/precip_data/US1OHSN0001.csv
# ✅ Processed and merged: /content/precip_data/MXN00010108.csv
# ✅ Processed and merged: /content/precip_data/USC00453826.csv
# ✅ Processed and merged: /content/precip_data/US1KSHV0002.csv
# ✅ Processed and merged: /content/precip_data/US1WAYK0024.csv
# ✅ Processed and merged: /content/precip_data/US1UTWG0004.csv
# ✅ Processed and merged: /content/precip_data/US1INLK0059.csv
# ✅ Processed and merged: /content/precip_data/US1CASD0199.csv
# ✅ Processed and merged: /content/precip_data/USC00357354.csv
# ✅ Processed and merged: /content/precip_data/US1TXWM0333.csv
# ✅ Processed and merged: /content/precip_data/US1KSGY0039.csv
# ✅ Processed and merged: /content/precip_data/USC00509865.csv
# ✅ Processed and merged: /content/precip_data/US1INHR0003.csv
# ✅ Processed and merged: /content/precip_data/US1NMRA0048.csv
# ✅ Processed and merged: /content/precip_data/US1CAOR0021.csv
# ✅ Processed and merged: /content/precip_data/US1INHM0048.csv
# ✅ Processed and merged: /content/precip_data/USC00363047.csv
# ✅ Processed and merged: /content/precip_data/CA00810I001.csv
# ✅ Processed and merged: /content/precip_data/USC00220585.csv
# ✅ Processed and merged: /content/precip_data/USC00352855.csv
# ✅ Processed and merged: /content/precip_data/US10PHEL007.csv
# ✅ Processed and merged: /content/precip_data/US1FLHL0018.csv
# ✅ Processed and merged: /content/precip_data/USC00021248.csv
# ✅ Processed and merged: /content/precip_data/US1AZYV0189.csv
# ✅ Processed and merged: /content/precip_data/US1NMSF0062.csv
# ✅ Processed and merged: /content/precip_data/USC00014060.csv
# ✅ Processed and merged: /content/precip_data/USC00366225.csv
# ✅ Processed and merged: /content/precip_data/US1COSG0021.csv
# ✅ Processed and merged: /content/precip_data/MXN00015103.csv
# ✅ Processed and merged: /content/precip_data/US1MODT0011.csv
# ✅ Processed and merged: /content/precip_data/US1NYTG0030.csv
# ✅ Processed and merged: /content/precip_data/CA004019085.csv
# ✅ Processed and merged: /content/precip_data/CA00401FFDB.csv
# ✅ Processed and merged: /content/precip_data/CA004012485.csv
# ✅ Processed and merged: /content/precip_data/USC00183795.csv
# ✅ Processed and merged: /content/precip_data/USC00179547.csv
# ✅ Processed and merged: /content/precip_data/USC00502015.csv
# ✅ Processed and merged: /content/precip_data/CA007051041.csv
# ✅ Processed and merged: /content/precip_data/USC00413646.csv
# ✅ Processed and merged: /content/precip_data/US1MNSC0047.csv
# ✅ Processed and merged: /content/precip_data/CA003020031.csv
# ✅ Processed and merged: /content/precip_data/MXN00026262.csv
# ✅ Processed and merged: /content/precip_data/USC00242317.csv
# ✅ Processed and merged: /content/precip_data/MXN00017066.csv
# ✅ Processed and merged: /content/precip_data/USC00401986.csv
# ✅ Processed and merged: /content/precip_data/USC00237506.csv
# ✅ Processed and merged: /content/precip_data/MXN00019146.csv
# ✅ Processed and merged: /content/precip_data/CA0030221LG.csv
# ✅ Processed and merged: /content/precip_data/US1ARYL0010.csv
# ✅ Processed and merged: /content/precip_data/US1TXHRR211.csv
# ✅ Processed and merged: /content/precip_data/US1NCRB0005.csv
# ✅ Processed and merged: /content/precip_data/US1VALD0029.csv
# ✅ Processed and merged: /content/precip_data/US1ORJC0005.csv
# ✅ Processed and merged: /content/precip_data/US1COHF0055.csv
# ✅ Processed and merged: /content/precip_data/CA005040230.csv
# ✅ Processed and merged: /content/precip_data/USW00063826.csv
# ✅ Processed and merged: /content/precip_data/USC00204104.csv
# ✅ Processed and merged: /content/precip_data/US1WYLM0011.csv
# ✅ Processed and merged: /content/precip_data/US1WYHS0005.csv
# ✅ Processed and merged: /content/precip_data/US1CARV0060.csv
# ✅ Processed and merged: /content/precip_data/CA008403098.csv
# ✅ Processed and merged: /content/precip_data/US1NYOD0014.csv
# ✅ Processed and merged: /content/precip_data/US1COJF0514.csv
# ✅ Processed and merged: /content/precip_data/US1TXAG0001.csv
# ✅ Processed and merged: /content/precip_data/US1WISC0063.csv
# ✅ Processed and merged: /content/precip_data/US1INPK0004.csv
# ✅ Processed and merged: /content/precip_data/CA1AB000024.csv
# ✅ Processed and merged: /content/precip_data/US1ILKN0118.csv
# ✅ Processed and merged: /content/precip_data/US1TXKY0003.csv
# ✅ Processed and merged: /content/precip_data/CA001162683.csv
# ✅ Processed and merged: /content/precip_data/MXN00020506.csv
# ✅ Processed and merged: /content/precip_data/US10FRON016.csv
# ✅ Processed and merged: /content/precip_data/MXN00001047.csv
# ✅ Processed and merged: /content/precip_data/US1CODN0333.csv
# ✅ Processed and merged: /content/precip_data/US1WIOC0011.csv
# ✅ Processed and merged: /content/precip_data/USC00308403.csv
# ✅ Processed and merged: /content/precip_data/US1CEDA4438.csv
# ✅ Processed and merged: /content/precip_data/US1IAPL0010.csv
# ✅ Processed and merged: /content/precip_data/US10DOUG031.csv
# ✅ Processed and merged: /content/precip_data/US1NYSF0024.csv
# ✅ Processed and merged: /content/precip_data/US1WISC0079.csv
# ✅ Processed and merged: /content/precip_data/US1ILPL0002.csv
# ✅ Processed and merged: /content/precip_data/US1WYAB0050.csv
# ✅ Processed and merged: /content/precip_data/US1TNWN0123.csv
# ✅ Processed and merged: /content/precip_data/CA007026754.csv
# ✅ Processed and merged: /content/precip_data/USC00469554.csv
# ✅ Processed and merged: /content/precip_data/US1MSSM0004.csv
# ✅ Processed and merged: /content/precip_data/US1TXGP0154.csv
# ✅ Processed and merged: /content/precip_data/CA006120795.csv
# ✅ Processed and merged: /content/precip_data/US1UTGR0002.csv
# ✅ Processed and merged: /content/precip_data/US1SCHR0132.csv
# ✅ Processed and merged: /content/precip_data/US1TXGP0002.csv
# ✅ Processed and merged: /content/precip_data/CA007028946.csv
# ✅ Processed and merged: /content/precip_data/CA1AB000046.csv
# ✅ Processed and merged: /content/precip_data/US1TXVC0027.csv
# ✅ Processed and merged: /content/precip_data/USC00225705.csv
# ✅ Processed and merged: /content/precip_data/USC00299342.csv
# ✅ Processed and merged: /content/precip_data/USC00160349.csv
# ✅ Processed and merged: /content/precip_data/MXN00028193.csv
# ✅ Processed and merged: /content/precip_data/USC00143855.csv
# ✅ Processed and merged: /content/precip_data/US1MOHT0006.csv
# ✅ Processed and merged: /content/precip_data/USC00356213.csv
# ✅ Processed and merged: /content/precip_data/MXN00019120.csv
# ✅ Processed and merged: /content/precip_data/US1MNSL0175.csv
# ✅ Processed and merged: /content/precip_data/US1KSAL0005.csv
# ✅ Processed and merged: /content/precip_data/CA001197530.csv
# ✅ Processed and merged: /content/precip_data/CA002100LRP.csv
# ✅ Processed and merged: /content/precip_data/USC00132235.csv
# ✅ Processed and merged: /content/precip_data/US1CANV0019.csv
# ✅ Processed and merged: /content/precip_data/US1COBO0464.csv
# ✅ Processed and merged: /content/precip_data/US1INWB0023.csv
# ✅ Processed and merged: /content/precip_data/US1MEYK0080.csv
# ✅ Processed and merged: /content/precip_data/US10YORK019.csv
# ✅ Processed and merged: /content/precip_data/US1ILUN0003.csv
# ✅ Processed and merged: /content/precip_data/MXN00019144.csv
# ✅ Processed and merged: /content/precip_data/MXN00014067.csv
# ✅ Processed and merged: /content/precip_data/US1PAYR0015.csv
# ✅ Processed and merged: /content/precip_data/US1AZMR0618.csv
# ✅ Processed and merged: /content/precip_data/US1MEYK0070.csv
# ✅ Processed and merged: /content/precip_data/US1LAEB0036.csv
# ✅ Processed and merged: /content/precip_data/MXN00012034.csv
# ✅ Processed and merged: /content/precip_data/US1MNCK0047.csv
# ✅ Processed and merged: /content/precip_data/USC00207089.csv
# ✅ Processed and merged: /content/precip_data/USC00028214.csv
# ✅ Processed and merged: /content/precip_data/US1NMCR0019.csv
# ✅ Processed and merged: /content/precip_data/USC00051939.csv
# ✅ Processed and merged: /content/precip_data/MXN00010028.csv
# ✅ Processed and merged: /content/precip_data/USC00473651.csv
# ✅ Processed and merged: /content/precip_data/US1NJCM0021.csv
# ✅ Processed and merged: /content/precip_data/USC00041161.csv
# ✅ Processed and merged: /content/precip_data/US1TXBLC034.csv
# ✅ Processed and merged: /content/precip_data/US1UTDV0042.csv
# ✅ Processed and merged: /content/precip_data/US1CALK0014.csv
# ✅ Processed and merged: /content/precip_data/USC00018403.csv
# ✅ Processed and merged: /content/precip_data/USC00311624.csv
# ✅ Processed and merged: /content/precip_data/US1VAFX0041.csv
# ✅ Processed and merged: /content/precip_data/US1INMR0065.csv
# ✅ Processed and merged: /content/precip_data/CA003015345.csv
# ✅ Processed and merged: /content/precip_data/US1COLA0017.csv
# ✅ Processed and merged: /content/precip_data/US1COCS0012.csv
# ✅ Processed and merged: /content/precip_data/US1AZYV0148.csv
# ✅ Processed and merged: /content/precip_data/US1OHSC0008.csv
# ✅ Processed and merged: /content/precip_data/US1SCGT0002.csv
# ✅ Processed and merged: /content/precip_data/US1ALLD0034.csv
# ✅ Processed and merged: /content/precip_data/US1KYTG0003.csv
# ✅ Processed and merged: /content/precip_data/US1MNGR0004.csv
# ✅ Processed and merged: /content/precip_data/US1FLMA0035.csv
# ✅ Processed and merged: /content/precip_data/US1TXCML141.csv
# ✅ Processed and merged: /content/precip_data/US1MOGR0105.csv
# ✅ Processed and merged: /content/precip_data/US1MOPT0008.csv
# ✅ Processed and merged: /content/precip_data/USC00264037.csv
# ✅ Processed and merged: /content/precip_data/MXN00025097.csv
# ✅ Processed and merged: /content/precip_data/USC00254110.csv
# ✅ Processed and merged: /content/precip_data/US1COMF0027.csv
# ✅ Processed and merged: /content/precip_data/MXN00032104.csv
# ✅ Processed and merged: /content/precip_data/CA004065220.csv
# ✅ Processed and merged: /content/precip_data/USC00154882.csv
# ✅ Processed and merged: /content/precip_data/US1FLHL0043.csv
# ✅ Processed and merged: /content/precip_data/US1OHFF0009.csv
# ✅ Processed and merged: /content/precip_data/US1NJWR0024.csv
# ✅ Processed and merged: /content/precip_data/MXN00011040.csv
# ✅ Processed and merged: /content/precip_data/USC00416497.csv
# ✅ Processed and merged: /content/precip_data/US1OHHY0003.csv
# ✅ Processed and merged: /content/precip_data/US1OHFR0106.csv
# ✅ Processed and merged: /content/precip_data/US1MTPR0012.csv
# ✅ Processed and merged: /content/precip_data/USC00428668.csv
# ✅ Processed and merged: /content/precip_data/USC00475477.csv
# ✅ Processed and merged: /content/precip_data/USC00191147.csv
# ✅ Processed and merged: /content/precip_data/US10NUCK028.csv
# ✅ Processed and merged: /content/precip_data/US1NJMN0048.csv
# ✅ Processed and merged: /content/precip_data/US1COME0153.csv
# ✅ Processed and merged: /content/precip_data/US1GAFT0037.csv
# ✅ Processed and merged: /content/precip_data/CA006128320.csv
# ✅ Processed and merged: /content/precip_data/CA003035198.csv
# ✅ Processed and merged: /content/precip_data/USC00101313.csv
# ✅ Processed and merged: /content/precip_data/MXN00015345.csv
# ✅ Processed and merged: /content/precip_data/USC00367956.csv
# ✅ Processed and merged: /content/precip_data/USC00512092.csv
# ✅ Processed and merged: /content/precip_data/US1ORLA0147.csv
# ✅ Processed and merged: /content/precip_data/US1MNDK0181.csv
# ✅ Processed and merged: /content/precip_data/US1ALEL0016.csv
# ✅ Processed and merged: /content/precip_data/USC00208967.csv
# ✅ Processed and merged: /content/precip_data/CA004013770.csv
# ✅ Processed and merged: /content/precip_data/USC00293855.csv
# ✅ Processed and merged: /content/precip_data/USC00447280.csv
# ✅ Processed and merged: /content/precip_data/USW00093114.csv
# ✅ Processed and merged: /content/precip_data/US1KSDK0011.csv
# ✅ Processed and merged: /content/precip_data/US1ALTS0022.csv
# ✅ Processed and merged: /content/precip_data/US1CAMT0005.csv
# ✅ Processed and merged: /content/precip_data/USC00443583.csv
# ✅ Processed and merged: /content/precip_data/USW00014609.csv
# ✅ Processed and merged: /content/precip_data/USC00456400.csv
# ✅ Processed and merged: /content/precip_data/US10DUND003.csv
# ✅ Processed and merged: /content/precip_data/USC00153837.csv
# ✅ Processed and merged: /content/precip_data/USC00417942.csv
# ✅ Processed and merged: /content/precip_data/CA003063684.csv
# ✅ Processed and merged: /content/precip_data/CA1QC000088.csv
# ✅ Processed and merged: /content/precip_data/US1UTDV0047.csv
# ✅ Processed and merged: /content/precip_data/US1OHWR0039.csv
# ✅ Processed and merged: /content/precip_data/US1NCCM0095.csv
# ✅ Processed and merged: /content/precip_data/US1CORT0026.csv
# ✅ Processed and merged: /content/precip_data/US1WIWS0030.csv
# ✅ Processed and merged: /content/precip_data/USC00463544.csv
# ✅ Processed and merged: /content/precip_data/USC00417707.csv
# ✅ Processed and merged: /content/precip_data/MXN00030062.csv
# ✅ Processed and merged: /content/precip_data/US1FLBV0042.csv
# ✅ Processed and merged: /content/precip_data/MXN00030094.csv
# ✅ Processed and merged: /content/precip_data/USC00111841.csv
# ✅ Processed and merged: /content/precip_data/US1COLR0925.csv
# ✅ Processed and merged: /content/precip_data/CA008502400.csv
# ✅ Processed and merged: /content/precip_data/USC00402360.csv
# ✅ Processed and merged: /content/precip_data/CA003032650.csv
# ✅ Processed and merged: /content/precip_data/US1OHER0017.csv
# ✅ Processed and merged: /content/precip_data/USC00248028.csv
# ✅ Processed and merged: /content/precip_data/USC00256490.csv
# ✅ Processed and merged: /content/precip_data/USC00512450.csv
# ✅ Processed and merged: /content/precip_data/MXN00015291.csv
# ✅ Processed and merged: /content/precip_data/USC00221235.csv
# ✅ Processed and merged: /content/precip_data/US1LAEB0047.csv
# ✅ Processed and merged: /content/precip_data/USC00482233.csv
# ✅ Processed and merged: /content/precip_data/CA006012198.csv
# ✅ Processed and merged: /content/precip_data/USC00162525.csv
# ✅ Processed and merged: /content/precip_data/USC00347012.csv
# ✅ Processed and merged: /content/precip_data/US1NMCB0007.csv
# ✅ Processed and merged: /content/precip_data/USC00462462.csv
# ✅ Processed and merged: /content/precip_data/USS0007H06S.csv
# ✅ Processed and merged: /content/precip_data/MXN00012027.csv
# ✅ Processed and merged: /content/precip_data/USC00452645.csv
# ✅ Processed and merged: /content/precip_data/US1NCCM0013.csv
# ✅ Processed and merged: /content/precip_data/US1NJOC0038.csv
# ✅ Processed and merged: /content/precip_data/US1ILLV0021.csv
# ✅ Processed and merged: /content/precip_data/USC00354042.csv
# ✅ Processed and merged: /content/precip_data/USC00193985.csv
# ✅ Processed and merged: /content/precip_data/US1TXGP0063.csv
# ✅ Processed and merged: /content/precip_data/US1COEP0061.csv
# ✅ Processed and merged: /content/precip_data/MXXLP337877.csv
# ✅ Processed and merged: /content/precip_data/CA006102840.csv
# ✅ Processed and merged: /content/precip_data/USC00412436.csv
# ✅ Processed and merged: /content/precip_data/USC00365816.csv
# ✅ Processed and merged: /content/precip_data/MXN00018084.csv
# ✅ Processed and merged: /content/precip_data/CA1SK000099.csv
# ✅ Processed and merged: /content/precip_data/USC00024864.csv
# ✅ Processed and merged: /content/precip_data/USC00027370.csv
# ✅ Processed and merged: /content/precip_data/MXN00030008.csv
# ✅ Processed and merged: /content/precip_data/US1IAPL0008.csv
# ✅ Processed and merged: /content/precip_data/USC00279525.csv
# ✅ Processed and merged: /content/precip_data/USC00029652.csv
# ✅ Processed and merged: /content/precip_data/USS0011D08S.csv
# ✅ Processed and merged: /content/precip_data/US1MELN0008.csv
# ✅ Processed and merged: /content/precip_data/MXN00015117.csv
# ✅ Processed and merged: /content/precip_data/MXN00010024.csv
# ✅ Processed and merged: /content/precip_data/US1WISB0031.csv
# ✅ Processed and merged: /content/precip_data/USS0050N05S.csv
# ✅ Processed and merged: /content/precip_data/USC00416257.csv
# ✅ Processed and merged: /content/precip_data/USC00355424.csv
# ✅ Processed and merged: /content/precip_data/US10SAUN012.csv
# ✅ Processed and merged: /content/precip_data/US1WASP0011.csv
# ✅ Processed and merged: /content/precip_data/USC00356426.csv
# ✅ Processed and merged: /content/precip_data/US1MEYK0048.csv
# ✅ Processed and merged: /content/precip_data/US1WIMC0020.csv
# ✅ Processed and merged: /content/precip_data/US1FLBY0026.csv
# ✅ Processed and merged: /content/precip_data/US1MAES0025.csv
# ✅ Processed and merged: /content/precip_data/US1NJCM0034.csv
# ✅ Processed and merged: /content/precip_data/US1NJSS0058.csv
# ✅ Processed and merged: /content/precip_data/USC00421750.csv
# ✅ Processed and merged: /content/precip_data/USW00023111.csv
# ✅ Processed and merged: /content/precip_data/US1KSEL0014.csv
# ✅ Processed and merged: /content/precip_data/US1GAFS0036.csv
# ✅ Processed and merged: /content/precip_data/US1NCPK0039.csv
# ✅ Processed and merged: /content/precip_data/US1CAAL0001.csv
# ✅ Processed and merged: /content/precip_data/US1NMLE0003.csv
# ✅ Processed and merged: /content/precip_data/US1INJH0008.csv
# ✅ Processed and merged: /content/precip_data/US1NYDT0049.csv
# ✅ Processed and merged: /content/precip_data/US1SCBF0078.csv
# ✅ Processed and merged: /content/precip_data/US1FLAL0014.csv
# ✅ Processed and merged: /content/precip_data/USC00465323.csv
# ✅ Processed and merged: /content/precip_data/US1FLFL0050.csv
# ✅ Processed and merged: /content/precip_data/USC00366396.csv
# ✅ Processed and merged: /content/precip_data/CA006118252.csv
# ✅ Processed and merged: /content/precip_data/US1SCHM0004.csv
# ✅ Processed and merged: /content/precip_data/US1IDAD0063.csv
# ✅ Processed and merged: /content/precip_data/USC00045372.csv
# ✅ Processed and merged: /content/precip_data/CA003057243.csv
# ✅ Processed and merged: /content/precip_data/US1NHHL0019.csv
# ✅ Processed and merged: /content/precip_data/USW00053120.csv
# ✅ Processed and merged: /content/precip_data/CA003076366.csv
# ✅ Processed and merged: /content/precip_data/MXN00028264.csv
# ✅ Processed and merged: /content/precip_data/USW00054779.csv
# ✅ Processed and merged: /content/precip_data/USC00148240.csv
# ✅ Processed and merged: /content/precip_data/US1KSST0007.csv
# ✅ Processed and merged: /content/precip_data/US1INVN0031.csv
# ✅ Processed and merged: /content/precip_data/CA006111145.csv
# ✅ Processed and merged: /content/precip_data/US1TXDA0097.csv
# ✅ Processed and merged: /content/precip_data/US1ORCC0125.csv
# ✅ Processed and merged: /content/precip_data/USC00256100.csv
# ✅ Processed and merged: /content/precip_data/US1IDEL0011.csv
# ✅ Processed and merged: /content/precip_data/US1TXDN0068.csv
# ✅ Processed and merged: /content/precip_data/USC00190655.csv
# ✅ Processed and merged: /content/precip_data/US1FLMT0033.csv
# ✅ Processed and merged: /content/precip_data/US1ILDK0005.csv
# ✅ Processed and merged: /content/precip_data/CA006112775.csv
# ✅ Processed and merged: /content/precip_data/USC00028268.csv
# ✅ Processed and merged: /content/precip_data/US1COJF0444.csv
# ✅ Processed and merged: /content/precip_data/US10YORK042.csv
# ✅ Processed and merged: /content/precip_data/USC00405187.csv
# ✅ Processed and merged: /content/precip_data/US1MAMD0069.csv
# ✅ Processed and merged: /content/precip_data/US1IAVB0011.csv
# ✅ Processed and merged: /content/precip_data/USC00095811.csv
# ✅ Processed and merged: /content/precip_data/US1FLHB0069.csv
# ✅ Processed and merged: /content/precip_data/US1INSJ0059.csv
# ✅ Processed and merged: /content/precip_data/USC00108500.csv
# ✅ Processed and merged: /content/precip_data/USC00056559.csv
# ✅ Processed and merged: /content/precip_data/US1OHHM0035.csv
# ✅ Processed and merged: /content/precip_data/USC00233849.csv
# ✅ Processed and merged: /content/precip_data/US1NMLN0019.csv
# ✅ Processed and merged: /content/precip_data/US1SCGT0054.csv
# ✅ Processed and merged: /content/precip_data/CA003078000.csv
# ✅ Processed and merged: /content/precip_data/CA006114006.csv
# ✅ Processed and merged: /content/precip_data/CA004012720.csv
# ✅ Processed and merged: /content/precip_data/USC00048517.csv
# ✅ Processed and merged: /content/precip_data/USC00230817.csv
# ✅ Processed and merged: /content/precip_data/US1MOCD0016.csv
# ✅ Processed and merged: /content/precip_data/CA002304058.csv
# ✅ Processed and merged: /content/precip_data/US1ARMR0016.csv
# ✅ Processed and merged: /content/precip_data/US1MNMR0017.csv
# ✅ Processed and merged: /content/precip_data/USW00093828.csv
# ✅ Processed and merged: /content/precip_data/CA008404310.csv
# ✅ Processed and merged: /content/precip_data/US1CASN0025.csv
# ✅ Processed and merged: /content/precip_data/US1IAGN0001.csv
# ✅ Processed and merged: /content/precip_data/US1NMBR0373.csv
# ✅ Processed and merged: /content/precip_data/US1NCDR0010.csv
# ✅ Processed and merged: /content/precip_data/USC00148163.csv
# ✅ Processed and merged: /content/precip_data/US10SHER001.csv
# ✅ Processed and merged: /content/precip_data/US1TXDN0132.csv
# ✅ Processed and merged: /content/precip_data/USC00480027.csv
# ✅ Processed and merged: /content/precip_data/USC00291480.csv
# ✅ Processed and merged: /content/precip_data/US1TXBEL001.csv
# ✅ Processed and merged: /content/precip_data/MXN00022012.csv
# ✅ Processed and merged: /content/precip_data/USC00059045.csv
# ✅ Processed and merged: /content/precip_data/US1TXMCL073.csv
# ✅ Processed and merged: /content/precip_data/US1WYCV0014.csv
# ✅ Processed and merged: /content/precip_data/USC00044679.csv
# ✅ Processed and merged: /content/precip_data/USC00448220.csv
# ✅ Processed and merged: /content/precip_data/MXN00021247.csv
# ✅ Processed and merged: /content/precip_data/US1AZYV0063.csv
# ✅ Processed and merged: /content/precip_data/US1ORJC0113.csv
# ✅ Processed and merged: /content/precip_data/US1NJAT0011.csv
# ✅ Processed and merged: /content/precip_data/US1WAJF0045.csv
# ✅ Processed and merged: /content/precip_data/MXN00010161.csv
# ✅ Processed and merged: /content/precip_data/US1TXNU0091.csv
# ✅ Processed and merged: /content/precip_data/US1KYCM0002.csv
# ✅ Processed and merged: /content/precip_data/US1AZMR0277.csv
# ✅ Processed and merged: /content/precip_data/CA006157683.csv
# ✅ Processed and merged: /content/precip_data/USC00426560.csv
# ✅ Processed and merged: /content/precip_data/US1NMGR0020.csv
# ✅ Processed and merged: /content/precip_data/US1MECM0148.csv
# ✅ Processed and merged: /content/precip_data/US1MDAA0094.csv
# ✅ Processed and merged: /content/precip_data/US1COJK0024.csv
# ✅ Processed and merged: /content/precip_data/USC00408540.csv
# ✅ Processed and merged: /content/precip_data/US1TXFY0078.csv
# ✅ Processed and merged: /content/precip_data/USC00340782.csv
# ✅ Processed and merged: /content/precip_data/USC00049499.csv
# ✅ Processed and merged: /content/precip_data/US1SCCR0032.csv
# ✅ Processed and merged: /content/precip_data/USC00246893.csv
# ✅ Processed and merged: /content/precip_data/USC00025837.csv
# ✅ Processed and merged: /content/precip_data/US1ORCC0007.csv
# ✅ Processed and merged: /content/precip_data/US1TXKY0008.csv
# ✅ Processed and merged: /content/precip_data/US1ALJC0022.csv
# ✅ Processed and merged: /content/precip_data/CA1ON000901.csv
# ✅ Processed and merged: /content/precip_data/USC00141351.csv
# ✅ Processed and merged: /content/precip_data/US1IDAD0037.csv
# ✅ Processed and merged: /content/precip_data/USC00478589.csv
# ✅ Processed and merged: /content/precip_data/USC00305429.csv
# ✅ Processed and merged: /content/precip_data/US1TXWB0025.csv
# ✅ Processed and merged: /content/precip_data/US1KYWR0028.csv
# ✅ Processed and merged: /content/precip_data/US1KSDK0017.csv
# ✅ Processed and merged: /content/precip_data/MXN00026109.csv
# ✅ Processed and merged: /content/precip_data/US1NYSF0100.csv
# ✅ Processed and merged: /content/precip_data/US1NCDH0024.csv
# ✅ Processed and merged: /content/precip_data/US1FLHY0012.csv
# ✅ Processed and merged: /content/precip_data/US1WACK0031.csv
# ✅ Processed and merged: /content/precip_data/USC00517781.csv
# ✅ Processed and merged: /content/precip_data/MXN00015078.csv
# ✅ Processed and merged: /content/precip_data/USC00294400.csv
# ✅ Processed and merged: /content/precip_data/US1CAHM0079.csv
# ✅ Processed and merged: /content/precip_data/US1CAHM0036.csv
# ✅ Processed and merged: /content/precip_data/US1WYCM0027.csv
# ✅ Processed and merged: /content/precip_data/US1ILHM0002.csv
# ✅ Processed and merged: /content/precip_data/US1ILHD0002.csv
# ✅ Processed and merged: /content/precip_data/USC00249192.csv
# ✅ Processed and merged: /content/precip_data/US1FLVL0070.csv
# ✅ Processed and merged: /content/precip_data/US1MSJF0001.csv
# ✅ Processed and merged: /content/precip_data/USC00335573.csv
# ✅ Processed and merged: /content/precip_data/USC00243373.csv
# ✅ Processed and merged: /content/precip_data/US1OHMY0005.csv
# ✅ Processed and merged: /content/precip_data/USC00273535.csv
# ✅ Processed and merged: /content/precip_data/USC00161380.csv
# ✅ Processed and merged: /content/precip_data/US1COEP0420.csv
# ✅ Processed and merged: /content/precip_data/USC00467502.csv
# ✅ Processed and merged: /content/precip_data/US1NCRN0001.csv
# ✅ Processed and merged: /content/precip_data/MXN00008244.csv
# ✅ Processed and merged: /content/precip_data/USC00416747.csv
# ✅ Processed and merged: /content/precip_data/US1ILWN0041.csv
# ✅ Processed and merged: /content/precip_data/USC00413321.csv
# ✅ Processed and merged: /content/precip_data/US1TXSP0018.csv
# ✅ Processed and merged: /content/precip_data/US1KSDG0058.csv
# ✅ Processed and merged: /content/precip_data/USC00362671.csv
# ✅ Processed and merged: /content/precip_data/USW00023272.csv
# ✅ Processed and merged: /content/precip_data/USW00012935.csv
# ✅ Processed and merged: /content/precip_data/USC00227701.csv
# ✅ Processed and merged: /content/precip_data/USC00172751.csv
# ✅ Processed and merged: /content/precip_data/US1ILWL0151.csv
# ✅ Processed and merged: /content/precip_data/MXN00028199.csv
# ✅ Processed and merged: /content/precip_data/USC00230824.csv
# ✅ Processed and merged: /content/precip_data/CA008504060.csv
# ✅ Processed and merged: /content/precip_data/CA005061770.csv
# ✅ Processed and merged: /content/precip_data/MXN00029043.csv
# ✅ Processed and merged: /content/precip_data/US1KSDG0085.csv
# ✅ Processed and merged: /content/precip_data/USC00247214.csv
# ✅ Processed and merged: /content/precip_data/US1CTMD0022.csv
# ✅ Processed and merged: /content/precip_data/USC00410580.csv
# ✅ Processed and merged: /content/precip_data/US1TXGD0008.csv
# ✅ Processed and merged: /content/precip_data/USC00448941.csv
# ✅ Processed and merged: /content/precip_data/US1WISC0024.csv
# ✅ Processed and merged: /content/precip_data/MXN00028131.csv
# ✅ Processed and merged: /content/precip_data/US1MTCH0001.csv
# ✅ Processed and merged: /content/precip_data/US1NHMR0024.csv
# ✅ Processed and merged: /content/precip_data/CA002402340.csv
# ✅ Processed and merged: /content/precip_data/US1FLCT0008.csv
# ✅ Processed and merged: /content/precip_data/USC00236726.csv
# ✅ Processed and merged: /content/precip_data/US1ILLK0075.csv
# ✅ Processed and merged: /content/precip_data/US1TXBRT007.csv
# ✅ Processed and merged: /content/precip_data/US1WASN0083.csv
# ✅ Processed and merged: /content/precip_data/CA001018FJ5.csv
# ✅ Processed and merged: /content/precip_data/US1LAST0022.csv
# ✅ Processed and merged: /content/precip_data/CA006093004.csv
# ✅ Processed and merged: /content/precip_data/US1NCWL0010.csv
# ✅ Processed and merged: /content/precip_data/US1WISC0004.csv
# ✅ Processed and merged: /content/precip_data/US1WVKN0031.csv
# ✅ Processed and merged: /content/precip_data/US1DENC0040.csv
# ✅ Processed and merged: /content/precip_data/USC00247505.csv
# ✅ Processed and merged: /content/precip_data/US1ORLC0028.csv
# ✅ Processed and merged: /content/precip_data/US1TXWT0014.csv
# ✅ Processed and merged: /content/precip_data/US1WIWN0012.csv
# ✅ Processed and merged: /content/precip_data/US1ALSH0012.csv
# ✅ Processed and merged: /content/precip_data/USC00450257.csv
# ✅ Processed and merged: /content/precip_data/USC00300707.csv
# ✅ Processed and merged: /content/precip_data/US1CODG0217.csv
# ✅ Processed and merged: /content/precip_data/US1TXBLC003.csv
# ✅ Processed and merged: /content/precip_data/US1WAIS0001.csv
# ✅ Processed and merged: /content/precip_data/USC00035694.csv
# ✅ Processed and merged: /content/precip_data/US1ORLN0017.csv
# ✅ Processed and merged: /content/precip_data/USC00488000.csv
# ✅ Processed and merged: /content/precip_data/US1RIPR0106.csv
# ✅ Processed and merged: /content/precip_data/US1INLK0071.csv
# ✅ Processed and merged: /content/precip_data/US1NCCN0002.csv
# ✅ Processed and merged: /content/precip_data/USC00410712.csv
# ✅ Processed and merged: /content/precip_data/USC00323696.csv
# ✅ Processed and merged: /content/precip_data/USS0006N04S.csv
# ✅ Processed and merged: /content/precip_data/USC00262948.csv
# ✅ Processed and merged: /content/precip_data/US1MNBU0062.csv
# ✅ Processed and merged: /content/precip_data/US1KSGY0016.csv
# ✅ Processed and merged: /content/precip_data/CA001024638.csv
# ✅ Processed and merged: /content/precip_data/US1WIRK0002.csv
# ✅ Processed and merged: /content/precip_data/US1SDFR0008.csv
# ✅ Processed and merged: /content/precip_data/US1TXMDN023.csv
# ✅ Processed and merged: /content/precip_data/US1VAJC0025.csv
# ✅ Processed and merged: /content/precip_data/USW00013301.csv
# ✅ Processed and merged: /content/precip_data/USC00034934.csv
# ✅ Processed and merged: /content/precip_data/US1MSPR0008.csv
# ✅ Processed and merged: /content/precip_data/US1SCDC0019.csv
# ✅ Processed and merged: /content/precip_data/US1WYSL0007.csv
# ✅ Processed and merged: /content/precip_data/US10PIER004.csv
# ✅ Processed and merged: /content/precip_data/US1NCPK0034.csv
# ✅ Processed and merged: /content/precip_data/US1INSH0004.csv
# ✅ Processed and merged: /content/precip_data/USC00018391.csv
# ✅ Processed and merged: /content/precip_data/US1DAKO4144.csv
# ✅ Processed and merged: /content/precip_data/USC00514625.csv
# ✅ Processed and merged: /content/precip_data/MXN00030139.csv
# ✅ Processed and merged: /content/precip_data/CA003074743.csv
# ✅ Processed and merged: /content/precip_data/USS0007M27S.csv
# ✅ Processed and merged: /content/precip_data/US1FLBV0052.csv
# ✅ Processed and merged: /content/precip_data/US1MION0003.csv
# ✅ Processed and merged: /content/precip_data/USW00013988.csv
# ✅ Processed and merged: /content/precip_data/USC00448448.csv
# ✅ Processed and merged: /content/precip_data/USC00162151.csv
# ✅ Processed and merged: /content/precip_data/US1ILMCL072.csv
# ✅ Processed and merged: /content/precip_data/US1NCCR0030.csv
# ✅ Processed and merged: /content/precip_data/US1SCDC0001.csv
# ✅ Processed and merged: /content/precip_data/CA008205120.csv
# ✅ Processed and merged: /content/precip_data/US1FLBV0001.csv
# ✅ Processed and merged: /content/precip_data/MXN00030145.csv
# ✅ Processed and merged: /content/precip_data/US1MAMD0008.csv
# ✅ Processed and merged: /content/precip_data/US1OHMM0027.csv
# ✅ Processed and merged: /content/precip_data/USW00014896.csv
# ✅ Processed and merged: /content/precip_data/US1WACH0023.csv
# ✅ Processed and merged: /content/precip_data/US1WYCR0016.csv
# ✅ Processed and merged: /content/precip_data/US1SCKR0057.csv
# ✅ Processed and merged: /content/precip_data/US1TXDA0021.csv
# ✅ Processed and merged: /content/precip_data/CA005023265.csv
# ✅ Processed and merged: /content/precip_data/USC00486165.csv
# ✅ Processed and merged: /content/precip_data/US1TXKR0053.csv
# ✅ Processed and merged: /content/precip_data/US1NELA0032.csv
# ✅ Processed and merged: /content/precip_data/USC00246138.csv
# ✅ Processed and merged: /content/precip_data/CA1BC000034.csv
# ✅ Processed and merged: /content/precip_data/US1CODN0179.csv
# ✅ Processed and merged: /content/precip_data/CA006142284.csv
# ✅ Processed and merged: /content/precip_data/US1MNML0012.csv
# ✅ Processed and merged: /content/precip_data/CA00101QFEG.csv
# ✅ Processed and merged: /content/precip_data/USC00453512.csv
# ✅ Processed and merged: /content/precip_data/USC00061093.csv
# ✅ Processed and merged: /content/precip_data/US1AZMR0015.csv
# ✅ Processed and merged: /content/precip_data/US10THAY009.csv
# ✅ Processed and merged: /content/precip_data/US1GALN0003.csv
# ✅ Processed and merged: /content/precip_data/US1CAPC0049.csv
# ✅ Processed and merged: /content/precip_data/USC00332305.csv
# ✅ Processed and merged: /content/precip_data/USC00247314.csv
# ✅ Processed and merged: /content/precip_data/US1NCPD0019.csv
# ✅ Processed and merged: /content/precip_data/MXN00024189.csv
# ✅ Processed and merged: /content/precip_data/US1NMSM0012.csv
# ✅ Processed and merged: /content/precip_data/USC00026482.csv
# ✅ Processed and merged: /content/precip_data/MXN00018068.csv
# ✅ Processed and merged: /content/precip_data/US1ILCK0229.csv
# ✅ Processed and merged: /content/precip_data/USC00230127.csv
# ✅ Processed and merged: /content/precip_data/MXN00005147.csv
# ✅ Processed and merged: /content/precip_data/USC00314788.csv
# ✅ Processed and merged: /content/precip_data/US1NCED0007.csv
# ✅ Processed and merged: /content/precip_data/US1AZPM0101.csv
# ✅ Processed and merged: /content/precip_data/USC00464408.csv
# ✅ Processed and merged: /content/precip_data/CA0030156H6.csv
# ✅ Processed and merged: /content/precip_data/US1TNSL0019.csv
# ✅ Processed and merged: /content/precip_data/US1NYSL0017.csv
# ✅ Processed and merged: /content/precip_data/US1MDHW0019.csv
# ✅ Processed and merged: /content/precip_data/USC00299095.csv
# ✅ Processed and merged: /content/precip_data/USC00318053.csv
# ✅ Processed and merged: /content/precip_data/US1MIOT0001.csv
# ✅ Processed and merged: /content/precip_data/USS0020K13S.csv
# ✅ Processed and merged: /content/precip_data/USC00509494.csv
# ✅ Processed and merged: /content/precip_data/US1NVDG0024.csv
# ✅ Processed and merged: /content/precip_data/US1COLR0735.csv
# ✅ Processed and merged: /content/precip_data/US1NDWR0012.csv
# ✅ Processed and merged: /content/precip_data/MXN00015064.csv
# ✅ Processed and merged: /content/precip_data/US1SCSP0104.csv
# ✅ Processed and merged: /content/precip_data/USC00207180.csv
# ✅ Processed and merged: /content/precip_data/CA006153676.csv
# ✅ Processed and merged: /content/precip_data/US1NYWN0010.csv
# ✅ Processed and merged: /content/precip_data/USS0007E12S.csv
# ✅ Processed and merged: /content/precip_data/MXN00024127.csv
# ✅ Processed and merged: /content/precip_data/US1GAFL0003.csv
# ✅ Processed and merged: /content/precip_data/US1ARFK0044.csv
# ✅ Processed and merged: /content/precip_data/US1KYHY0003.csv
# ✅ Processed and merged: /content/precip_data/US1INNB0015.csv
# ✅ Processed and merged: /content/precip_data/USC00253589.csv
# ✅ Processed and merged: /content/precip_data/US1TXSA0002.csv
# ✅ Processed and merged: /content/precip_data/CA007050200.csv
# ✅ Processed and merged: /content/precip_data/US1KSTH0017.csv
# ✅ Processed and merged: /content/precip_data/USC00311913.csv
# ✅ Processed and merged: /content/precip_data/US1DENC0008.csv
# ✅ Processed and merged: /content/precip_data/USC00263205.csv
# ✅ Processed and merged: /content/precip_data/US1ALLD0055.csv
# ✅ Processed and merged: /content/precip_data/US1HIHI0034.csv
# ✅ Processed and merged: /content/precip_data/USC00052731.csv
# ✅ Processed and merged: /content/precip_data/USW00014854.csv
# ✅ Processed and merged: /content/precip_data/US1WAKG0178.csv
# ✅ Processed and merged: /content/precip_data/USC00249067.csv
# ✅ Processed and merged: /content/precip_data/US1WIVL0009.csv
# ✅ Processed and merged: /content/precip_data/US1FLSM0011.csv
# ✅ Processed and merged: /content/precip_data/US10DOUG046.csv
# ✅ Processed and merged: /content/precip_data/CA003065512.csv
# ✅ Processed and merged: /content/precip_data/US1ILVR0038.csv
# ✅ Processed and merged: /content/precip_data/US1CATH0010.csv
# ✅ Processed and merged: /content/precip_data/CA00109G775.csv
# ✅ Processed and merged: /content/precip_data/US1NCWK0022.csv
# ✅ Processed and merged: /content/precip_data/USC00418920.csv
# ✅ Processed and merged: /content/precip_data/US1GAAP0004.csv
# ✅ Processed and merged: /content/precip_data/US1MTYS0030.csv
# ✅ Processed and merged: /content/precip_data/US1OHMM0011.csv
# ✅ Processed and merged: /content/precip_data/USC00257700.csv
# ✅ Processed and merged: /content/precip_data/CA008102160.csv
# ✅ Processed and merged: /content/precip_data/US10SEWA022.csv
# ✅ Processed and merged: /content/precip_data/USC00248857.csv
# ✅ Processed and merged: /content/precip_data/US1INAL0036.csv
# ✅ Processed and merged: /content/precip_data/USC00055352.csv
# ✅ Processed and merged: /content/precip_data/USC00226638.csv
# ✅ Processed and merged: /content/precip_data/USC00442216.csv
# ✅ Processed and merged: /content/precip_data/CA00102BFHH.csv
# ✅ Processed and merged: /content/precip_data/US1MTSG0007.csv
# ✅ Processed and merged: /content/precip_data/MXN00015060.csv
# ✅ Processed and merged: /content/precip_data/USC00411629.csv
# ✅ Processed and merged: /content/precip_data/USC00296532.csv
# ✅ Processed and merged: /content/precip_data/USC00402305.csv
# ✅ Processed and merged: /content/precip_data/USC00507738.csv
# ✅ Processed and merged: /content/precip_data/US1TXGA0043.csv
# ✅ Processed and merged: /content/precip_data/CA005010240.csv
# ✅ Processed and merged: /content/precip_data/US1VAFQ0021.csv
# ✅ Processed and merged: /content/precip_data/US1CAHM0042.csv
# ✅ Processed and merged: /content/precip_data/US1NJWR0007.csv
# ✅ Processed and merged: /content/precip_data/USC00011615.csv
# ✅ Processed and merged: /content/precip_data/US1MECM0133.csv
# ✅ Processed and merged: /content/precip_data/US1INHR0002.csv
# ✅ Processed and merged: /content/precip_data/US1MOOS0010.csv
# ✅ Processed and merged: /content/precip_data/MXN00030371.csv
# ✅ Processed and merged: /content/precip_data/CA007113280.csv
# ✅ Processed and merged: /content/precip_data/US1OHCY0039.csv
# ✅ Processed and merged: /content/precip_data/USC00298872.csv
# ✅ Processed and merged: /content/precip_data/USC00264038.csv
# ✅ Processed and merged: /content/precip_data/US1TXFA0007.csv
# ✅ Processed and merged: /content/precip_data/USC00411033.csv
# ✅ Processed and merged: /content/precip_data/CA1NS000064.csv
# ✅ Processed and merged: /content/precip_data/USC00244538.csv
# ✅ Processed and merged: /content/precip_data/CA007055121.csv
# ✅ Processed and merged: /content/precip_data/US1KYJF0087.csv
# ✅ Processed and merged: /content/precip_data/MXN00009034.csv
# ✅ Processed and merged: /content/precip_data/US1OHAT0002.csv
# ✅ Processed and merged: /content/precip_data/US1TNWS0023.csv
# ✅ Processed and merged: /content/precip_data/US1OHSM0017.csv
# ✅ Processed and merged: /content/precip_data/US1ARSL0010.csv
# ✅ Processed and merged: /content/precip_data/US1NCHW0068.csv
# ✅ Processed and merged: /content/precip_data/USW00014853.csv
# ✅ Processed and merged: /content/precip_data/USC00043392.csv
# ✅ Processed and merged: /content/precip_data/US10CLAY024.csv
# ✅ Processed and merged: /content/precip_data/US1WIKN0035.csv
# ✅ Processed and merged: /content/precip_data/USC00216571.csv
# ✅ Processed and merged: /content/precip_data/US1VACH0001.csv
# ✅ Processed and merged: /content/precip_data/US1WIPR0014.csv
# ✅ Processed and merged: /content/precip_data/US1KYFR0010.csv
# ✅ Processed and merged: /content/precip_data/CA007061560.csv
# ✅ Processed and merged: /content/precip_data/USC00412084.csv
# ✅ Processed and merged: /content/precip_data/US1MEWL0003.csv
# ✅ Processed and merged: /content/precip_data/CA008500400.csv
# ✅ Processed and merged: /content/precip_data/MXN00014117.csv
# ✅ Processed and merged: /content/precip_data/US1TXWM0054.csv
# ✅ Processed and merged: /content/precip_data/US1WASJ0051.csv
# ✅ Processed and merged: /content/precip_data/USC00102392.csv
# ✅ Processed and merged: /content/precip_data/USC00049177.csv
# ✅ Processed and merged: /content/precip_data/USC00025560.csv
# ✅ Processed and merged: /content/precip_data/US1TNWT0022.csv
# ✅ Processed and merged: /content/precip_data/CA006107699.csv
# ✅ Processed and merged: /content/precip_data/USC00086251.csv
# ✅ Processed and merged: /content/precip_data/USC00143759.csv
# ✅ Processed and merged: /content/precip_data/MXN00014174.csv
# ✅ Processed and merged: /content/precip_data/USC00086612.csv
# ✅ Processed and merged: /content/precip_data/US10SCOT027.csv
# ✅ Processed and merged: /content/precip_data/CA1MB000252.csv
# ✅ Processed and merged: /content/precip_data/US1WACK0072.csv
# ✅ Processed and merged: /content/precip_data/US1NCBC0040.csv
# ✅ Processed and merged: /content/precip_data/CA1SK000190.csv
# ✅ Processed and merged: /content/precip_data/US1ORLC0012.csv
# ✅ Processed and merged: /content/precip_data/US1OHFF0023.csv
# ✅ Processed and merged: /content/precip_data/US1TXFY0072.csv
# ✅ Processed and merged: /content/precip_data/USC00339358.csv
# ✅ Processed and merged: /content/precip_data/US1COWE0274.csv
# ✅ Processed and merged: /content/precip_data/US1TXGP0091.csv
# ✅ Processed and merged: /content/precip_data/US1NMSF0105.csv
# ✅ Processed and merged: /content/precip_data/CA003034795.csv
# ✅ Processed and merged: /content/precip_data/USC00155694.csv
# ✅ Processed and merged: /content/precip_data/US1PAWN0013.csv
# ✅ Processed and merged: /content/precip_data/US1CODG0067.csv
# ✅ Processed and merged: /content/precip_data/MXN00025171.csv
# ...
# ✅ Processed and merged: /content/precip_data/USC00417388.csv
# ✅ Processed and merged: /content/precip_data/USC00155668.csv
# ✅ Processed and merged: /content/precip_data/US1UTSL0121.csv
# ✅ Processed and merged: /content/precip_data/USC00392852.csv
# ✅ Processed and merged: /content/precip_data/USC00440766.csv
# ✅ Processed and merged: /content/precip_data/USC00193821.csv
# ✅ Processed and merged: /content/precip_data/USC00059275.csv
# ✅ Processed and merged: /content/precip_data/US1NVLY0024.csv
# ✅ Processed and merged: /content/precip_data/US1MOFSA021.csv
# ✅ Processed and merged: /content/precip_data/US1ORTL0004.csv
# ✅ Processed and merged: /content/precip_data/USC00293405.csv
# ✅ Processed and merged: /content/precip_data/US1MORL0003.csv
# ✅ Processed and merged: /content/precip_data/US1COFM0021.csv
# ✅ Processed and merged: /content/precip_data/CA00119BLM0.csv
# ✅ Processed and merged: /content/precip_data/USC00244462.csv
# ✅ Processed and merged: /content/precip_data/US1WIPT0010.csv
# ✅ Processed and merged: /content/precip_data/US1TXBRN008.csv
# ✅ Processed and merged: /content/precip_data/US1MOBT0011.csv
# ✅ Processed and merged: /content/precip_data/US1TXBST187.csv
# ✅ Processed and merged: /content/precip_data/CA003053669.csv
# ✅ Processed and merged: /content/precip_data/USC00347264.csv
# ✅ Processed and merged: /content/precip_data/USC00040758.csv
# ✅ Processed and merged: /content/precip_data/USC00405351.csv
# ✅ Processed and merged: /content/precip_data/USC00410380.csv
# ✅ Processed and merged: /content/precip_data/CA1PE000046.csv
# ✅ Processed and merged: /content/precip_data/US1MNPS0006.csv
# ✅ Processed and merged: /content/precip_data/US1VTCL0044.csv
# ✅ Processed and merged: /content/precip_data/US1NMGR0109.csv
# ✅ Processed and merged: /content/precip_data/US1MNPK0021.csv
# ✅ Processed and merged: /content/precip_data/USC00412295.csv
# ✅ Processed and merged: /content/precip_data/USC00335024.csv
# ✅ Processed and merged: /content/precip_data/US1KYCN0001.csv
# ✅ Processed and merged: /content/precip_data/US1TXGP0158.csv
# ✅ Processed and merged: /content/precip_data/US1NCCL0026.csv
# ✅ Processed and merged: /content/precip_data/USC00364019.csv
# ✅ Processed and merged: /content/precip_data/US1VTWS0012.csv
# ✅ Processed and merged: /content/precip_data/CA006135583.csv
# ✅ Processed and merged: /content/precip_data/CA00616RKR0.csv
# ✅ Processed and merged: /content/precip_data/US1TXAS0006.csv
# ✅ Processed and merged: /content/precip_data/US1MNPK0023.csv
# ✅ Processed and merged: /content/precip_data/USW00013702.csv
# ✅ Processed and merged: /content/precip_data/US1TXSM0031.csv
# ✅ Processed and merged: /content/precip_data/US1TXGV0024.csv
# ✅ Processed and merged: /content/precip_data/US1SCAK0033.csv
# ✅ Processed and merged: /content/precip_data/CA003016860.csv
# ✅ Processed and merged: /content/precip_data/US1OKCN0019.csv
# ✅ Processed and merged: /content/precip_data/US1ILLS0045.csv
# ✅ Processed and merged: /content/precip_data/US1NCGS0063.csv
# ✅ Processed and merged: /content/precip_data/US1VAMD0003.csv
# ✅ Processed and merged: /content/precip_data/US1MSHR0005.csv
# ✅ Processed and merged: /content/precip_data/USC00305816.csv
# ✅ Processed and merged: /content/precip_data/USC00355770.csv
# ✅ Processed and merged: /content/precip_data/US1VAAM0002.csv
# ✅ Processed and merged: /content/precip_data/US1MNWR0013.csv
# ✅ Processed and merged: /content/precip_data/US1CTNL0006.csv
# ✅ Processed and merged: /content/precip_data/MXN00024023.csv
# ✅ Processed and merged: /content/precip_data/US1VACL0007.csv
# ✅ Processed and merged: /content/precip_data/US1KSSM0012.csv
# ✅ Processed and merged: /content/precip_data/US1COLN0060.csv
# ✅ Processed and merged: /content/precip_data/CA003065160.csv
# ✅ Processed and merged: /content/precip_data/US1WIWW0027.csv
# ✅ Processed and merged: /content/precip_data/USC00291254.csv
# ✅ Processed and merged: /content/precip_data/US1MAWR0044.csv
# ✅ Processed and merged: /content/precip_data/USC00330745.csv
# ✅ Processed and merged: /content/precip_data/US1ORCB0009.csv
# ✅ Processed and merged: /content/precip_data/US1NCHN0046.csv
# ✅ Processed and merged: /content/precip_data/US1GADK0044.csv
# ✅ Processed and merged: /content/precip_data/US1FLOK0020.csv
# ✅ Processed and merged: /content/precip_data/US1SDHR0017.csv
# ✅ Processed and merged: /content/precip_data/CA004040587.csv
# ✅ Processed and merged: /content/precip_data/USW00024231.csv
# ✅ Processed and merged: /content/precip_data/US1ILCP0076.csv
# ✅ Processed and merged: /content/precip_data/US1COLR0688.csv
# ✅ Processed and merged: /content/precip_data/US1GAUN0001.csv
# ✅ Processed and merged: /content/precip_data/CA003012330.csv
# ✅ Processed and merged: /content/precip_data/US1TXMDN010.csv
# ✅ Processed and merged: /content/precip_data/USC00257840.csv
# ✅ Processed and merged: /content/precip_data/US1SCBF0064.csv
# ✅ Processed and merged: /content/precip_data/US1RIPR0084.csv
# ✅ Processed and merged: /content/precip_data/US1KSMS0021.csv
# ✅ Processed and merged: /content/precip_data/US1NJHN0059.csv
# ✅ Processed and merged: /content/precip_data/USC00156435.csv
# ✅ Processed and merged: /content/precip_data/USC00404517.csv
# ✅ Processed and merged: /content/precip_data/MXN00012031.csv
# ✅ Processed and merged: /content/precip_data/USC00143467.csv
# ✅ Processed and merged: /content/precip_data/USC00056318.csv
# ✅ Processed and merged: /content/precip_data/US1WYFM0008.csv
# ✅ Processed and merged: /content/precip_data/US1TXGG0010.csv
# ✅ Processed and merged: /content/precip_data/USC00253397.csv
# ✅ Processed and merged: /content/precip_data/US1TXHYS053.csv
# ✅ Processed and merged: /content/precip_data/US1CTFR0052.csv
# ✅ Processed and merged: /content/precip_data/US1RIPR0020.csv
# ✅ Processed and merged: /content/precip_data/MXN00026042.csv
# ✅ Processed and merged: /content/precip_data/USC00292604.csv
# ✅ Processed and merged: /content/precip_data/USC00015635.csv
# ✅ Processed and merged: /content/precip_data/US1TNMT0093.csv
# ✅ Processed and merged: /content/precip_data/USC00031132.csv
# ✅ Processed and merged: /content/precip_data/US1MNRC0003.csv
# ✅ Processed and merged: /content/precip_data/USC00035072.csv
# ✅ Processed and merged: /content/precip_data/USC00243434.csv
# ✅ Processed and merged: /content/precip_data/US1INKS0063.csv
# ✅ Processed and merged: /content/precip_data/USS0011K21S.csv
# ✅ Processed and merged: /content/precip_data/US1NCPR0010.csv
# ✅ Processed and merged: /content/precip_data/US1COLR1304.csv
# ✅ Processed and merged: /content/precip_data/MXN00002020.csv
# ✅ Processed and merged: /content/precip_data/US1KSEW0047.csv
# ✅ Processed and merged: /content/precip_data/US1TXEL0027.csv
# ✅ Processed and merged: /content/precip_data/US1TXCLD031.csv
# ✅ Processed and merged: /content/precip_data/US1MOFSA047.csv
# ✅ Processed and merged: /content/precip_data/USC00415259.csv
# ✅ Processed and merged: /content/precip_data/US1TNMN0002.csv
# ✅ Processed and merged: /content/precip_data/US1NJMN0064.csv
# ✅ Processed and merged: /content/precip_data/USC00044773.csv
# ✅ Processed and merged: /content/precip_data/CA001120630.csv
# ✅ Processed and merged: /content/precip_data/US1MOFSA025.csv
# ✅ Processed and merged: /content/precip_data/US1VASC0002.csv
# ✅ Processed and merged: /content/precip_data/USC00042327.csv
# ✅ Processed and merged: /content/precip_data/CA002403800.csv
# ✅ Processed and merged: /content/precip_data/US1ARNW0004.csv
# ✅ Processed and merged: /content/precip_data/CA001184716.csv
# ✅ Processed and merged: /content/precip_data/US1YORK4303.csv
# ✅ Processed and merged: /content/precip_data/US1VAPT0009.csv
# ✅ Processed and merged: /content/precip_data/US1TXLT0004.csv
# ✅ Processed and merged: /content/precip_data/USC00160244.csv
# ✅ Processed and merged: /content/precip_data/US1GACT0019.csv
# ✅ Processed and merged: /content/precip_data/US1NCFR0037.csv
# ✅ Processed and merged: /content/precip_data/USC00517457.csv
# ✅ Processed and merged: /content/precip_data/US1COPK0061.csv
# ✅ Processed and merged: /content/precip_data/USC00506760.csv
# ✅ Processed and merged: /content/precip_data/MXN00030308.csv
# ✅ Processed and merged: /content/precip_data/USC00420506.csv
# ✅ Processed and merged: /content/precip_data/USC00296119.csv
# ✅ Processed and merged: /content/precip_data/US1MNLK0043.csv
# ✅ Processed and merged: /content/precip_data/USC00235704.csv
# ✅ Processed and merged: /content/precip_data/US1HIHN0032.csv
# ✅ Processed and merged: /content/precip_data/US1INJH0037.csv
# ✅ Processed and merged: /content/precip_data/USC00109840.csv
# ✅ Processed and merged: /content/precip_data/US1ORLN0094.csv
# ✅ Processed and merged: /content/precip_data/US1ORPK0013.csv
# ✅ Processed and merged: /content/precip_data/US1FLOK0049.csv
# ✅ Processed and merged: /content/precip_data/US1NCCR0114.csv
# ✅ Processed and merged: /content/precip_data/US1MDMG0040.csv
# ✅ Processed and merged: /content/precip_data/CA003056510.csv
# ✅ Processed and merged: /content/precip_data/USC00485686.csv
# ✅ Processed and merged: /content/precip_data/US1LANT0005.csv
# ✅ Processed and merged: /content/precip_data/USC00414780.csv
# ✅ Processed and merged: /content/precip_data/USC00258928.csv
# ✅ Processed and merged: /content/precip_data/US1MNDK0043.csv
# ✅ Processed and merged: /content/precip_data/USC00156104.csv
# ✅ Processed and merged: /content/precip_data/USC00186670.csv
# ✅ Processed and merged: /content/precip_data/USC00045100.csv
# ✅ Processed and merged: /content/precip_data/CA008103400.csv
# ✅ Processed and merged: /content/precip_data/US1ILWL0039.csv
# ✅ Processed and merged: /content/precip_data/USC00518543.csv
# ✅ Processed and merged: /content/precip_data/USC00142478.csv
# ✅ Processed and merged: /content/precip_data/USC00214376.csv
# ✅ Processed and merged: /content/precip_data/USC00308733.csv
# ✅ Processed and merged: /content/precip_data/US1MOTX0004.csv
# ✅ Processed and merged: /content/precip_data/US1NCGL0008.csv
# ✅ Processed and merged: /content/precip_data/MXN00015209.csv
# ✅ Processed and merged: /content/precip_data/US1NJUN0007.csv
# ✅ Processed and merged: /content/precip_data/US1COLR1362.csv
# ✅ Processed and merged: /content/precip_data/US10LINC048.csv
# ✅ Processed and merged: /content/precip_data/US1CUST4385.csv
# ✅ Processed and merged: /content/precip_data/CA005020625.csv
# ✅ Processed and merged: /content/precip_data/US1SCCK0013.csv
# ✅ Processed and merged: /content/precip_data/USW00014934.csv
# ✅ Processed and merged: /content/precip_data/MXN00007169.csv
# ✅ Processed and merged: /content/precip_data/USC00428476.csv
# ✅ Processed and merged: /content/precip_data/CA001114741.csv
# ✅ Processed and merged: /content/precip_data/MXN00015034.csv
# ✅ Processed and merged: /content/precip_data/US1COOR0013.csv
# ✅ Processed and merged: /content/precip_data/US1NMVL0027.csv
# ✅ Processed and merged: /content/precip_data/MXN00024157.csv
# ✅ Processed and merged: /content/precip_data/US1TXHRR118.csv
# ✅ Processed and merged: /content/precip_data/US1WIDD0027.csv
# ✅ Processed and merged: /content/precip_data/US1GAMN0006.csv
# ✅ Processed and merged: /content/precip_data/MXN00029042.csv
# ✅ Processed and merged: /content/precip_data/USC00389122.csv
# ✅ Processed and merged: /content/precip_data/US1ILWL0068.csv
# ✅ Processed and merged: /content/precip_data/US1MOMD0009.csv
# ✅ Processed and merged: /content/precip_data/USC00355357.csv
# ✅ Processed and merged: /content/precip_data/US1TXER0011.csv
# ✅ Processed and merged: /content/precip_data/US1NJOC0033.csv
# ✅ Processed and merged: /content/precip_data/US1TXNU0011.csv
# ✅ Processed and merged: /content/precip_data/CA004017370.csv
# ✅ Processed and merged: /content/precip_data/USW00024015.csv
# ✅ Processed and merged: /content/precip_data/US1WYPT0016.csv
# ✅ Processed and merged: /content/precip_data/US1WIBT0024.csv
# ✅ Processed and merged: /content/precip_data/USC00427343.csv
# ✅ Processed and merged: /content/precip_data/USC00414556.csv
# ✅ Processed and merged: /content/precip_data/US1NYCN0018.csv
# ✅ Processed and merged: /content/precip_data/USC00092283.csv
# ✅ Processed and merged: /content/precip_data/US1SCLX0184.csv
# ✅ Processed and merged: /content/precip_data/US1NHMR0077.csv
# ✅ Processed and merged: /content/precip_data/US1NJCM0029.csv
# ✅ Processed and merged: /content/precip_data/CA1NB000061.csv
# ✅ Processed and merged: /content/precip_data/US1WIWW0012.csv
# ✅ Processed and merged: /content/precip_data/US1MSCP0004.csv
# ✅ Processed and merged: /content/precip_data/US10LINC033.csv
# ✅ Processed and merged: /content/precip_data/US1COJF0430.csv
# ✅ Processed and merged: /content/precip_data/USC00404987.csv
# ✅ Processed and merged: /content/precip_data/USC00359046.csv
# ✅ Processed and merged: /content/precip_data/USC00512144.csv
# ✅ Processed and merged: /content/precip_data/US1NJMN0073.csv
# ✅ Processed and merged: /content/precip_data/USC00153408.csv
# ✅ Processed and merged: /content/precip_data/US1SCGV0028.csv
# ✅ Processed and merged: /content/precip_data/USC00170272.csv
# ✅ Processed and merged: /content/precip_data/USC00045756.csv
# ✅ Processed and merged: /content/precip_data/CA1BC000120.csv
# ✅ Processed and merged: /content/precip_data/CA005062040.csv
# ✅ Processed and merged: /content/precip_data/US1NCSM0022.csv
# ✅ Processed and merged: /content/precip_data/US1COBO0241.csv
# ✅ Processed and merged: /content/precip_data/USC00456982.csv
# ✅ Processed and merged: /content/precip_data/USC00363293.csv
# ✅ Processed and merged: /content/precip_data/USC00140926.csv
# ✅ Processed and merged: /content/precip_data/US1ILGL0002.csv
# ✅ Processed and merged: /content/precip_data/USC00419282.csv
# ✅ Processed and merged: /content/precip_data/US1DCDC0009.csv
# ✅ Processed and merged: /content/precip_data/US1NYSF0065.csv
# ✅ Processed and merged: /content/precip_data/CA001135126.csv
# ✅ Processed and merged: /content/precip_data/USC00068436.csv
# ✅ Processed and merged: /content/precip_data/US1MISG0015.csv
# ✅ Processed and merged: /content/precip_data/US1TXBST134.csv
# ✅ Processed and merged: /content/precip_data/US1NCWT0020.csv
# ✅ Processed and merged: /content/precip_data/MXN00016129.csv
# ✅ Processed and merged: /content/precip_data/US1SCCR0015.csv
# ✅ Processed and merged: /content/precip_data/USC00356366.csv
# ✅ Processed and merged: /content/precip_data/USC00303864.csv
# ✅ Processed and merged: /content/precip_data/US1OKTL0003.csv
# ✅ Processed and merged: /content/precip_data/CA001105553.csv
# ✅ Processed and merged: /content/precip_data/USC00132999.csv
# ✅ Processed and merged: /content/precip_data/USC00180960.csv
# ✅ Processed and merged: /content/precip_data/USC00412676.csv
# ✅ Processed and merged: /content/precip_data/USC00409283.csv
# ✅ Processed and merged: /content/precip_data/CA001085064.csv
# ✅ Processed and merged: /content/precip_data/USC00057460.csv
# ✅ Processed and merged: /content/precip_data/US1WIWP0012.csv
# ✅ Processed and merged: /content/precip_data/MXN00019038.csv
# ✅ Processed and merged: /content/precip_data/USC00317056.csv
# ✅ Processed and merged: /content/precip_data/USW00022522.csv
# ✅ Processed and merged: /content/precip_data/USC00331390.csv
# ✅ Processed and merged: /content/precip_data/USC00147043.csv
# ✅ Processed and merged: /content/precip_data/USC00356550.csv
# ✅ Processed and merged: /content/precip_data/USC00245300.csv
# ✅ Processed and merged: /content/precip_data/US1ILRI0013.csv
# ✅ Processed and merged: /content/precip_data/US1MNRM0099.csv
# ✅ Processed and merged: /content/precip_data/US10NUCK019.csv
# ✅ Processed and merged: /content/precip_data/USC00412812.csv
# ✅ Processed and merged: /content/precip_data/US1MNSL0202.csv
# ✅ Processed and merged: /content/precip_data/CA006152114.csv
# ✅ Processed and merged: /content/precip_data/CA001172870.csv
# ✅ Processed and merged: /content/precip_data/CA001011920.csv
# ✅ Processed and merged: /content/precip_data/USC00358407.csv
# ✅ Processed and merged: /content/precip_data/MXN00024017.csv
# ✅ Processed and merged: /content/precip_data/CA008503630.csv
# ✅ Processed and merged: /content/precip_data/USC00415892.csv
# ✅ Processed and merged: /content/precip_data/USC00310901.csv
# ✅ Processed and merged: /content/precip_data/CA006158731.csv
# ✅ Processed and merged: /content/precip_data/US1TXCML190.csv
# ⚠️ Error log saved at /content/error_log.txt
# ✅ Merging complete! Data saved to /content/merged_precip_data.csv

# %%
#validating station IDs all start with MX, CA, and US after merge.
import pandas as pd

# Load the processed precipitation dataset
processed_precip_file = "/content/merged_precip_data.csv"
df = pd.read_csv(processed_precip_file, dtype=str)

# Ensure Station_ID column is cleaned
df["Station_ID"] = df["Station_ID"].str.strip()

# Define valid prefixes
VALID_PREFIXES = ("MX", "CA", "US")

# Find rows where Station_ID doesn't start with valid prefixes
invalid_ids = df[~df["Station_ID"].str.startswith(VALID_PREFIXES, na=False)]

# Display results
print(f"🚨 Found {invalid_ids.shape[0]} invalid Station_IDs.")
print(invalid_ids[["Station_ID", "Station_Name"]].head(20))  # Show sample

invalid_ids.to_csv("/content/drive/MyDrive/climate_data/invalid_station_ids.csv", index=False)
print("📁 Invalid Station_IDs saved to Google Drive.")
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# 🚨 Found 0 invalid Station_IDs.
# Empty DataFrame
# Columns: [Station_ID, Station_Name]
# Index: []
# 📁 Invalid Station_IDs saved to Google Drive.

# %%
#integrating metadata with raw data
import pandas as pd

# Define file paths
precip_data_file = "/content/merged_precip_data.csv"
precip_metadata_file = "/content/drive/MyDrive/climate_data/precip_metadata_filtered.csv"

# Read large precipitation file in chunks
chunksize = 500_000  # Adjust based on available RAM

precip_chunks = []
for chunk in pd.read_csv(precip_data_file, chunksize=chunksize):
    precip_chunks.append(chunk)

# Merge all chunks into a final DataFrame
precip_df = pd.concat(precip_chunks, ignore_index=True)
print(f"✅ Loaded precipitation data: {precip_df.shape}")

# Load station metadata
metadata_df = pd.read_csv(precip_metadata_file)
# Out:
# ✅ Loaded precipitation data: (16378268, 11)

# %%
#viewing samples of df
precip_df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Station_ID                              Station_Name  Latitude  Longitude  \
# 0  USC00336853                  "OH PROCTORVILLE DAM 27"     38.45   -82.3167
# 1  USC00336853                  "OH PROCTORVILLE DAM 27"     38.45   -82.3167
# 2  USC00336853                  "OH PROCTORVILLE DAM 27"     38.45   -82.3167
# 3  USC00336853                  "OH PROCTORVILLE DAM 27"     38.45   -82.3167
# 4  USC00336853                  "OH PROCTORVILLE DAM 27"     38.45   -82.3167
#
#    Elevation YearMonth  Precip_Value Measurement_Flag QC_Flag Source_Flag  \
# 0      171.0   1952-01         154.9              NaN     NaN           D
# 1      171.0   1952-02          46.1              NaN     NaN           D
# 2      171.0   1952-03         130.6              NaN     NaN           D
# 3      171.0   1952-04          93.2              NaN     NaN           D
# 4      171.0   1952-05         151.9              NaN     NaN           D
#
#    Source_Index
# 0       64867.0
# 1       64867.0
# 2       64867.0
# 3       64867.0
# 4       64867.0

# %%
#viewing samples of df
metadata_df.head()
# Out:
# /usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Station_ID  Latitude  Longitude  Elevation State  \
# 0  CA001010066   48.8667  -123.2833        4.0   NaN
# 1  CA001010235   48.4000  -123.4833       17.0   NaN
# 2  CA001010595   48.5833  -123.5167       85.0   NaN
# 3  CA001010720   48.5000  -124.0000      351.0   NaN
# 4  CA001010774   48.5000  -123.3500       61.0   NaN
#
#                 Station_Name  WMO_ID  First_Year  Last_Year
# 0             BC ACTIVE PASS   99999        1984       1996
# 1             BC ALBERT HEAD   99999        1971       1995
# 2  BC BAMBERTON OCEAN CEMENT   99999        1961       1980
# 3              BC BEAR CREEK   99999        1910       1971
# 4             BC BEAVER LAKE   99999        1894       1952

# %%
# Merge metadata with precipitation data
precip_final = precip_df.merge(metadata_df, on="Station_ID", how="left")

# Save the enriched dataset
precip_final_file = "/content/drive/MyDrive/climate_data/precip_final.csv"
precip_final.to_csv(precip_final_file, index=False)

print(f"✅ Merged dataset saved to {precip_final_file}")
# Out:
# ✅ Merged dataset saved to /content/drive/MyDrive/climate_data/precip_final.csv

# %%
#viewing random samples
precip_final.sample(5)
# Out:
#            Station_ID                            Station_Name_x  Latitude_x  \
# 9392505   USS0011G30S                 "ID SEDGWICK PEAK SNOTEL"     42.5200
# 1984348   USC00116558    "IL PALESTINE                     HCN"     38.9994
# 13099774  CA003023280                            "AB HILLSDOWN"     52.1667
# 6463178   USC00358797    "OR VALE                          HCN"     43.9814
# 11037550  US1GABN0001                      "GA BALDWIN 1.4 ESE"     34.4821
#
#           Longitude_x  Elevation_x  YearMonth  Precip_Value Measurement_Flag  \
# 9392505     -111.9600       2392.7     199408          48.1
# 1984348      -87.6139        136.6     190207          41.4
# 13099774    -113.5167        896.0     190801           6.7
# 6463178     -117.2439        682.8     194405          19.5
# 11037550     -83.5293        403.9     201810         117.4
#
#          QC_Flag Source_Flag  Source_Index  Latitude_y  Longitude_y  \
# 9392505                    D         73745     42.5200    -111.9600
# 1984348                    D         55277     38.9994     -87.6139
# 13099774                   D         25975     52.1667    -113.5167
# 6463178                    D         66081     43.9814    -117.2439
# 11037550                   D        999999     34.4821     -83.5293
#
#           Elevation_y State           Station_Name_y   WMO_ID  First_Year  \
# 9392505        2392.7   NaN  ID SEDGWICK PEAK SNOTEL  99999.0      1988.0
# 1984348         136.6   NaN             IL PALESTINE  99999.0      1882.0
# 13099774        896.0   NaN             AB HILLSDOWN  99999.0      1904.0
# 6463178         682.8   NaN                  OR VALE  99999.0      1891.0
# 11037550        403.9   NaN       GA BALDWIN 1.4 ESE  99999.0      2008.0
#
#           Last_Year
# 9392505      2024.0
# 1984348      2023.0
# 13099774     1960.0
# 6463178      2013.0
# 11037550     2024.0

# %%
#validating merged datasets
import pandas as pd
# Find Station_IDs missing in metadata
precip_data = pd.read_csv("/content/merged_precip_data.csv", usecols=["Station_ID"], dtype=str)
precip_metadata = pd.read_csv("/content/drive/MyDrive/climate_data/precip_metadata_filtered.csv", usecols=["Station_ID"], dtype=str)

missing_stations = precip_data[~precip_data["Station_ID"].isin(precip_metadata["Station_ID"])]
print(f"🚨 Missing Station_IDs in Metadata: {missing_stations.shape[0]}")
if not missing_stations.empty:
    print(missing_stations.head())
# Out:
# 🚨 Missing Station_IDs in Metadata: 0

# %%
#loading temperature metadata
import pandas as pd

# Define column widths based on the expected format
colspecs = [(0, 11), (12, 20), (21, 30), (31, 37), (38, None)]  # Adjust as needed

# Define column names
metadata_columns = ["Station_ID", "Latitude", "Longitude", "StnElev", "Station_Name"]

# Read the metadata file with fixed column widths
df_metadata = pd.read_fwf(TEMP_METADATA, colspecs=colspecs, header=None, names=metadata_columns)

# Convert Latitude and Longitude to float (to preserve negatives)
df_metadata["Latitude"] = pd.to_numeric(df_metadata["Latitude"], errors="coerce")
df_metadata["Longitude"] = pd.to_numeric(df_metadata["Longitude"], errors="coerce")

# Filter for stations in US, CA, MX only
df_metadata = df_metadata[df_metadata["Station_ID"].str.startswith(("US", "CA", "MX"))]

# Display the first few rows to verify longitude
print(df_metadata.head(10))
# Out:
#        Station_ID  Latitude  Longitude  StnElev               Station_Name
# 2404  CA001011500   48.9333  -123.7500     75.0                  CHEMAINUS
# 2405  CA001011920   48.5333  -123.3667     37.0                CORDOVA_BAY
# 2406  CA001011922   48.5167  -123.3667     26.0          CORDOVA_BAY_SOUTH
# 2407  CA001012008   48.4167  -123.7000     52.0                   COWICHAN
# 2408  CA001012010   48.7167  -123.5500      1.0  COWICHAN_BAY_CHERRY_POINT
# 2409  CA001012040   48.8167  -124.1333    177.0     COWICHAN_LAKE_FORESTRY
# 2410  CA001012055   48.8333  -124.0500    171.0              LAKE_COWICHAN
# 2411  CA001012475   48.4167  -123.2333     15.0           DISCOVERY_ISLAND
# 2412  CA001012550   48.7833  -123.7167      9.0                     DUNCAN
# 2413  CA001012570   48.7667  -123.6833      6.0            DUNCAN_FORESTRY

# %%
#extracting temperatures
import pandas as pd
import re

# Define file paths
TEMP_DATA = "/content/drive/MyDrive/climate_data/ghcnm.tavg.v4.0.1.20250127.qfe.dat"
TEMP_OUTPUT_FILE = "/content/processed_temps_only.csv"

# Function to extract temperatures
def extract_temperatures(line):
    """Extracts station ID, year, and 12 temperature values."""

    station_id = line[:11].strip()

    # 🚀 Filter: Keep only "MX", "CA", or "US" stations
    if not station_id.startswith(("MX", "CA", "US")):
        return None

    year = line[11:15].strip()
    element = line[15:19].strip()

    # Only process TAVG rows
    if element != "TAVG":
        return None

    # Regex: Extract numerical temperature values (ignore flags)
    pattern = r"(-?\d{1,4})\s*[A-Za-z\"'{}\[\]|&]*"
    matches = re.findall(pattern, line[19:].strip())

    # Ensure exactly 12 temperature values
    if len(matches) != 12:
        return None

    # Convert temperature values to Celsius (divide by 100)
    temperatures = [int(temp) / 100.0 for temp in matches]

    return [station_id, year] + temperatures  # Store station, year, and monthly temperatures

# Read and parse the file
parsed_rows = []
with open(TEMP_DATA, "r") as file:
    for line in file:
        parsed_line = extract_temperatures(line)
        if parsed_line:
            parsed_rows.append(parsed_line)

# Define column names
column_names = ["Station_ID", "Year"] + [f"{m:02d}_Temp" for m in range(1, 13)]

# Create DataFrame
df_temps = pd.DataFrame(parsed_rows, columns=column_names)

# Save to CSV
df_temps.to_csv(TEMP_OUTPUT_FILE, index=False)

print(f"✅ Step 1 complete: Temperatures extracted! Data saved to {TEMP_OUTPUT_FILE}")
print(df_temps.head(10))  # Preview data
# Out:
# ✅ Step 1 complete: Temperatures extracted! Data saved to /content/processed_temps_only.csv
#     Station_ID  Year  01_Temp  02_Temp  03_Temp  04_Temp  05_Temp  06_Temp  \
# 0  CA001011500  1961     5.01     6.14     7.10     8.97    12.89    17.05
# 1  CA001011500  1962     3.53     5.23     5.10     9.47    11.47    15.10
# 2  CA001011500  1963     1.55     7.46     6.41     9.12    12.81    15.75
# 3  CA001011500  1964     4.56     5.24     6.24     8.34    11.46    15.17
# 4  CA001011500  1965     2.73     4.72     5.95     9.09    11.44    15.82
# 5  CA001011500  1966     3.28     5.11     6.47     9.18    12.37    14.36
# 6  CA001011500  1967     4.60     5.51     5.41     7.69    12.75    17.90
# 7  CA001011500  1968     3.30     6.15     7.46     8.25    13.20    15.29
# 8  CA001011500  1969    -1.80     3.29     6.38     8.31    14.03    18.46
# 9  CA001011500  1970     3.62     6.45     7.03     8.22    11.79    17.11
#
#    07_Temp  08_Temp  09_Temp  10_Temp  11_Temp  12_Temp
# 0    19.82    20.15    14.09     9.30     5.01     3.41
# 1    17.71    16.63    14.80    11.08     7.23     5.45
# 2    16.65    18.50    17.08    11.30     6.22     4.90
# 3    17.05    16.92    13.85    10.63     5.04     1.60
# 4    19.02    18.35    14.01    11.38     7.34     4.01
# 5    16.96    18.22    15.80     9.95     6.73     5.84
# 6    18.63    20.66    16.72    10.70     6.75     3.72
# 7    19.03    16.95    14.75     9.47     6.55     1.39
# 8    18.03    16.26    14.76    10.13     6.88     5.38
# 9    17.85    17.70    13.63     9.52     5.68     2.97

# %%
#extracting flags into a single field
FLAG_OUTPUT_FILE = "/content/processed_flags_only.csv"

# Function to extract flags correctly
def extract_flags(line):
    """Extracts 12 sets of flags from a line while keeping them as a single field."""

    station_id = line[:11].strip()

    # 🚀 Filter: Keep only "MX", "CA", or "US" stations
    if not station_id.startswith(("MX", "CA", "US")):
        return None

    year = line[11:15].strip()
    element = line[15:19].strip()

    # Only process TAVG rows
    if element != "TAVG":
        return None

    # Regex: Extract flag values (ignoring temperatures)
    pattern = r"-?\d{1,4}\s*([A-Za-z\"'{}\[\]|&]*)"
    matches = re.findall(pattern, line[19:].strip())

    # Ensure exactly 12 flags are extracted
    if len(matches) != 12:
        return None

    return [station_id, year] + matches

# Read and parse flags from the file
parsed_flags = []
with open(TEMP_DATA, "r") as file:
    for line in file:
        parsed_line = extract_flags(line)
        if parsed_line:
            parsed_flags.append(parsed_line)

# Define column names for flags
column_names_flags = ["Station_ID", "Year"] + [f"{m:02d}_Flags" for m in range(1, 13)]

# Create DataFrame for flags
df_flags = pd.DataFrame(parsed_flags, columns=column_names_flags)

# Save to CSV
df_flags.to_csv(FLAG_OUTPUT_FILE, index=False)

print(f"✅ Step 2 complete: Flags extracted! Data saved to {FLAG_OUTPUT_FILE}")
print(df_flags.head(10))  # Preview data
# Out:
# ✅ Step 2 complete: Flags extracted! Data saved to /content/processed_flags_only.csv
#     Station_ID  Year 01_Flags 02_Flags 03_Flags 04_Flags 05_Flags 06_Flags  \
# 0  CA001011500  1961        E        E        E        E        E        E
# 1  CA001011500  1962        E        E        E        E        E        E
# 2  CA001011500  1963        E        E        E        E        E        E
# 3  CA001011500  1964        E        E        E        E        E        E
# 4  CA001011500  1965        E        E        E        E        E        E
# 5  CA001011500  1966        E        E        E        E        E        E
# 6  CA001011500  1967        E        E        E        E        E        E
# 7  CA001011500  1968        E        E        E        E        E        E
# 8  CA001011500  1969        E        E        E        E        E        E
# 9  CA001011500  1970        E        E        E        E        E        E
#
#   07_Flags 08_Flags 09_Flags 10_Flags 11_Flags 12_Flags
# 0        E        E        E        E        E        E
# 1        E        E        E        E        E        E
# 2        E        E        E        E        E        E
# 3        E        E        E        E        E        E
# 4        E        E        E        E        E        E
# 5        E        E        E        E        E        E
# 6        E        E        E        E        E        E
# 7        E        E        E        E        E        E
# 8        E        E        E        E        E        E
# 9        E        E        E        E        E        E

# %%
#sampling to ensure data looks accurate
df_flags.sample(10)
# Out:
#          Station_ID  Year 01_Flags 02_Flags 03_Flags 04_Flags 05_Flags  \
# 287572  USC00228530  1974        E        E        E        E        E
# 390210  USC00458903  2010        E        E        E        E        E
# 76867   CA004024160  1965        C        C        C        C        C
# 115998  CA006131415  1985        C        C        C        C        C
# 362131  USC00402957  1964        E        E        E        E        E
# 160784  CA008103050  1975        C        C        C        C        C
# 18208   CA001105155  1980        E        E        E        E        E
# 140393  CA007034395  1976        E        E        E        E        E
# 336683  USC00341900  1987        E        E        E        E        E
# 514567  USW00012826  1969      EXX      EXX      EXX      EXX      EXX
#
#        06_Flags 07_Flags 08_Flags 09_Flags 10_Flags 11_Flags 12_Flags
# 287572        E        E        E        E        E        E        E
# 390210        E        E        E        E        E        E        E
# 76867         E        C        C        C        C        C        C
# 115998        C        C        C        C        C        C        C
# 362131        E        E        E        E        E        E        E
# 160784        C        C        C        C        C        C        C
# 18208         E        E        E        E        E        E        E
# 140393        C        C        E        C        C        C        C
# 336683        E        E        E        E        E        E        E
# 514567      EXX      EXX      EXX      EXX      EXX      EXX      EXX

# %%
#merging temperature and flags
MERGED_OUTPUT_FILE = "/content/processed_temperature_data.csv"

# Load extracted temperature & flag datasets
df_temps = pd.read_csv(TEMP_OUTPUT_FILE)
df_flags = pd.read_csv(FLAG_OUTPUT_FILE)

# Merge temperature and flag data on Station_ID and Year
df_final = df_temps.merge(df_flags, on=["Station_ID", "Year"])

# 🚀 Apply filtering again just in case
df_final = df_final[df_final["Station_ID"].str.startswith(("MX", "CA", "US"))]

# Save merged dataset
df_final.to_csv(MERGED_OUTPUT_FILE, index=False)

print(f"✅ Step 3 complete: Data merged and saved to {MERGED_OUTPUT_FILE}")
print(df_final.head(10))  # Preview final structured output
# Out:
# ✅ Step 3 complete: Data merged and saved to /content/processed_temperature_data.csv
#     Station_ID  Year  01_Temp  02_Temp  03_Temp  04_Temp  05_Temp  06_Temp  \
# 0  CA001011500  1961     5.01     6.14     7.10     8.97    12.89    17.05
# 1  CA001011500  1962     3.53     5.23     5.10     9.47    11.47    15.10
# 2  CA001011500  1963     1.55     7.46     6.41     9.12    12.81    15.75
# 3  CA001011500  1964     4.56     5.24     6.24     8.34    11.46    15.17
# 4  CA001011500  1965     2.73     4.72     5.95     9.09    11.44    15.82
# 5  CA001011500  1966     3.28     5.11     6.47     9.18    12.37    14.36
# 6  CA001011500  1967     4.60     5.51     5.41     7.69    12.75    17.90
# 7  CA001011500  1968     3.30     6.15     7.46     8.25    13.20    15.29
# 8  CA001011500  1969    -1.80     3.29     6.38     8.31    14.03    18.46
# 9  CA001011500  1970     3.62     6.45     7.03     8.22    11.79    17.11
#
#    07_Temp  08_Temp  ...  03_Flags  04_Flags  05_Flags  06_Flags 07_Flags  \
# 0    19.82    20.15  ...         E         E         E         E        E
# 1    17.71    16.63  ...         E         E         E         E        E
# 2    16.65    18.50  ...         E         E         E         E        E
# 3    17.05    16.92  ...         E         E         E         E        E
# 4    19.02    18.35  ...         E         E         E         E        E
# 5    16.96    18.22  ...         E         E         E         E        E
# 6    18.63    20.66  ...         E         E         E         E        E
# 7    19.03    16.95  ...         E         E         E         E        E
# 8    18.03    16.26  ...         E         E         E         E        E
# 9    17.85    17.70  ...         E         E         E         E        E
#
#   08_Flags 09_Flags 10_Flags 11_Flags 12_Flags
# 0        E        E        E        E        E
# 1        E        E        E        E        E
# 2        E        E        E        E        E
# 3        E        E        E        E        E
# 4        E        E        E        E        E
# 5        E        E        E        E        E
# 6        E        E        E        E        E
# 7        E        E        E        E        E
# 8        E        E        E        E        E
# 9        E        E        E        E        E
#
# [10 rows x 26 columns]

# %%
#pivoting data into long format

# 🚀 Load Processed Data
df = pd.read_csv(MERGED_OUTPUT_FILE)

# 🚀 Apply Final Filter (Just to be Safe)
df = df[df["Station_ID"].str.startswith(("MX", "CA", "US"))]

# 🚀 Pivot Temperature Data
df_temp_long = df.melt(
    id_vars=["Station_ID", "Year"],
    value_vars=[f"{m:02d}_Temp" for m in range(1, 13)],
    var_name="Month",
    value_name="Temperature"
)

# 🚀 Pivot Flags Data
df_flags_long = df.melt(
    id_vars=["Station_ID", "Year"],
    value_vars=[f"{m:02d}_Flags" for m in range(1, 13)],
    var_name="Month",
    value_name="Flags"
)

# 🚀 Extract Month Number
df_temp_long["Month"] = df_temp_long["Month"].str[:2]
df_flags_long["Month"] = df_flags_long["Month"].str[:2]


# 🚀 Merge Temperatures & Flags
df_final = df_temp_long.merge(df_flags_long, on=["Station_ID", "Year", "Month"], how="left")

# 🚀 Create Final Date Column
df_final["Date"] = df_final["Year"].astype(str) + "-" + df_final["Month"]

# 🚀 Drop Unnecessary Columns
df_final = df_final.drop(columns=["Year", "Month"])

# 🚀 Save Final Structured Data
FINAL_OUTPUT_FILE = "/content/final_climate_data.csv"
df_final.to_csv(FINAL_OUTPUT_FILE, index=False)

print("✅ Transformation complete! Data saved to final_climate_data.csv")
print(df_final.head(10))  # Preview final structured output
# Out:
# ✅ Transformation complete! Data saved to final_climate_data.csv
#     Station_ID  Temperature Flags     Date
# 0  CA001011500         5.01     E  1961-01
# 1  CA001011500         3.53     E  1962-01
# 2  CA001011500         1.55     E  1963-01
# 3  CA001011500         4.56     E  1964-01
# 4  CA001011500         2.73     E  1965-01
# 5  CA001011500         3.28     E  1966-01
# 6  CA001011500         4.60     E  1967-01
# 7  CA001011500         3.30     E  1968-01
# 8  CA001011500        -1.80     E  1969-01
# 9  CA001011500         3.62     E  1970-01

# %%
df_final.sample(10)
# Out:
#           Station_ID  Temperature Flags     Date
# 3687974  USC00408540        24.07     E  1965-07
# 3763241  USR0000CWWC        13.97     E  1971-07
# 6456682  USC00406740         1.95     E  1968-12
# 2709449  USS0013C39S         7.77     T  2007-05
# 4651975  USC00047714        22.10     E  1979-09
# 4540064  CA006104165        17.61     C  1968-09
# 5544639  CA001035614         7.72     E  1962-11
# 1972928  USC00293840         5.69     E  2002-04
# 1699086  CA002101135        -0.98     E  1961-04
# 2793803  CA001128983        14.58     E  1981-06

# %%
#saving merged dataset as CSV
df_final.to_csv("/content/drive/MyDrive/climate_data/temp_final.csv", index=False)
print("✅ Merged dataset saved as temp_final.csv")

df_final.head()
# Out:
# ✅ Merged dataset saved as temp_final.csv
#     Station_ID  Temperature Flags     Date
# 0  CA001011500         5.01     E  1961-01
# 1  CA001011500         3.53     E  1962-01
# 2  CA001011500         1.55     E  1963-01
# 3  CA001011500         4.56     E  1964-01
# 4  CA001011500         2.73     E  1965-01

# %%
import pandas as pd

# Define file paths
temp_final_file = "/content/drive/MyDrive/climate_data/temp_final.csv"
precip_final_file = "/content/drive/MyDrive/climate_data/precip_final.csv"
merged_output_file = "/content/drive/MyDrive/climate_data/climate_merged_final.csv"

# 🚀 Load Datasets
df_temp = pd.read_csv(temp_final_file)
df_precip = pd.read_csv(precip_final_file)

# 🚀 Ensure Date Fields Match
df_temp.rename(columns={"Date": "YearMonth"}, inplace=True)  # Match date column name
df_precip["YearMonth"] = df_precip["YearMonth"].astype(str)  # Ensure it's a string

# Ensure Latitude and Longitude have four decimal place
df_precip["Latitude_y"] = df_precip["Latitude_y"].astype(float).map(lambda x: f"{x:.4f}")
df_precip["Longitude_y"] = df_precip["Longitude_y"].astype(float).map(lambda x: f"{x:.4f}")


# 🚀 Merge on Station_ID & Date (YearMonth)
df_merged = df_temp.merge(df_precip, on=["Station_ID", "YearMonth"], how="inner")

# 🚀 Rename Columns for Clarity
df_merged.rename(columns={
    "YearMonth": "Date",
    "Latitude_y": "Latitude",
    "Longitude_y": "Longitude",
    "Elevation_y": "Elevation",
    "Station_Name_y": "StationName",
    "Temperature": "Temp_celsius",
    "Precip_Value": "Precip_mm",
    "Flags": "TempFlags",
    "Measurement_Flag": "Precip_MeasurementFlag",
    "QC_Flag": "Precip_QCFlag",
    "Source_Flag": "Precip_SourceFlag",
    "Source_Index": "Precip_SourceIndex",
    "First_Year": "Precip_FirstYear",
    "Last_Year": "Precip_LastYear"
}, inplace=True)

# 🚀 Select Only Required Columns
df_merged = df_merged[[
    "Station_ID", "Date", "Latitude", "Longitude", "Elevation", "State", "StationName",
    "Temp_celsius", "Precip_mm", "TempFlags", "Precip_MeasurementFlag", "Precip_QCFlag",
    "Precip_SourceFlag", "Precip_SourceIndex", "Precip_FirstYear", "Precip_LastYear"
]]

# 🚀 Save Final Merged Dataset
df_merged.to_csv(merged_output_file, index=False)

print(f"✅ Merging complete! Data saved to {merged_output_file}")
print(df_merged.head(10))  # Preview final structured output
# Out:
# <ipython-input-16-6880b8112527>:10: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_precip = pd.read_csv(precip_final_file)
# ✅ Merging complete! Data saved to /content/drive/MyDrive/climate_data/climate_merged_final.csv
#     Station_ID     Date Latitude  Longitude  Elevation State   StationName  \
# 0  CA001011500  1961-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
# 1  CA001011500  1962-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
# 2  CA001011500  1963-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
# 3  CA001011500  1964-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
# 4  CA001011500  1965-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
# 5  CA001011500  1966-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
# 6  CA001011500  1967-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
# 7  CA001011500  1968-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
# 8  CA001011500  1969-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
# 9  CA001011500  1970-01  48.9333  -123.7500       75.0   NaN  BC CHEMAINUS
#
#    Temp_celsius  Precip_mm TempFlags Precip_MeasurementFlag Precip_QCFlag  \
# 0          5.01      372.3         E                    NaN           NaN
# 1          3.53      107.4         E                    NaN           NaN
# 2          1.55       33.5         E                    NaN           NaN
# 3          4.56      302.5         E                    NaN           NaN
# 4          2.73      169.4         E                    NaN           NaN
# 5          3.28      256.2         E                    NaN           NaN
# 6          4.60      328.5         E                    NaN           NaN
# 7          3.30      356.1         E                    NaN           NaN
# 8         -1.80      123.4         E                    NaN           NaN
# 9          3.62      173.1         E                    NaN           NaN
#
#   Precip_SourceFlag  Precip_SourceIndex  Precip_FirstYear  Precip_LastYear
# 0                 D             23584.0              1919             2024
# 1                 D             23584.0              1919             2024
# 2                 D             23584.0              1919             2024
# 3                 D             23584.0              1919             2024
# 4                 D             23584.0              1919             2024
# 5                 D             23584.0              1919             2024
# 6                 D             23584.0              1919             2024
# 7                 D             23584.0              1919             2024
# 8                 D             23584.0              1919             2024
# 9                 D             23584.0              1919             2024

# %%
df_merged.sample(10)
# Out:
#           Station_ID     Date Latitude  Longitude  Elevation State  \
# 1128486  CA001195250  1986-10  58.9333  -125.7667      837.0   NaN
# 1041576  CA00701S001  1997-09  46.8000   -71.3833       60.0   NaN
# 586564   USS0005N16S  1997-05  36.9900  -105.2600     3230.9   NaN
# 777402   CA00503B1ER  2005-07  50.1833   -96.0667      268.0   NaN
# 67071    CA008205990  1965-01  45.3667   -63.2667       40.0   NaN
# 1308635  CA008401550  1980-11  48.7667   -56.6000      154.0   NaN
# 786839   CA006141095  1985-07  43.3333   -80.3167      268.0   NaN
# 946876   USC00175736  2004-08  44.6353   -70.0003      146.3   NaN
# 544436   CA007026836  1961-05  45.1333   -74.3500       53.0   NaN
# 401541   CA005021220  1997-04  49.0333   -97.5667      253.0   NaN
#
#                         StationName  Temp_celsius  Precip_mm TempFlags  \
# 1128486              BC MUNCHO LAKE          3.62       90.5         C
# 1041576  QC QUEBEC/JEAN LESAGE INTL         11.89       72.3         C
# 586564     NM NORTH COSTILLA SNOTEL          4.94       91.3         T
# 777402                    MB PINAWA         18.92       86.0         C
# 67071                      NS TRURO         -7.53       86.4         C
# 1308635             NL EXPLOITS DAM          1.52      135.2         C
# 786839        ON CAMBRIDGE GALT MOE         19.23       70.2         C
# 946876                ME NEW SHARON         18.93      151.0         E
# 544436                 QC ST ANICET         11.27       60.5         C
# 401541              MB GRETNA (AUT)         -0.78       11.6         C
#
#         Precip_MeasurementFlag Precip_QCFlag Precip_SourceFlag  \
# 1128486                    NaN           NaN                 D
# 1041576                      A           NaN                 D
# 586564                     NaN           NaN                 D
# 777402                     NaN           NaN                 D
# 67071                      NaN           NaN                 D
# 1308635                    NaN           NaN                 D
# 786839                     NaN           NaN                 D
# 946876                     NaN           NaN                 D
# 544436                     NaN           NaN                 D
# 401541                       D           NaN                 D
#
#          Precip_SourceIndex  Precip_FirstYear  Precip_LastYear
# 1128486             25164.0              1970             2013
# 1041576             29742.0              1993             2024
# 586564              73467.0              1979             2024
# 777402              27987.0              1992             2024
# 67071               31029.0              1960             2002
# 1308635             31188.0              1956             2006
# 786839              29128.0              1879             1993
# 946876              57877.0              1993             2024
# 544436              29886.0              1960             2024
# 401541              27794.0              1885             2024
